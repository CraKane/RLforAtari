# %%
# optional Google drive integration - this will allow you to save and resume training, and may speed up redownloading the dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **SAC**

# %%
import gym
import collections
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch import nn
import torch.backends.cudnn as cudnn
import logging
from torch.autograd import Variable

# hyperparameters
learning_rate = 0.001
gamma = 0.9
buffer_limit = 50000
batch_size = 32
video_every = 5
print_every = 5
MSELoss = torch.nn.MSELoss()

class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)

    def put(self, transition):
        self.buffer.append(transition)

    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []

        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])

        return torch.tensor(s_lst, dtype=torch.float).cuda(), torch.tensor(a_lst).cuda(), \
               torch.tensor(r_lst).cuda(), torch.tensor(s_prime_lst, dtype=torch.float).cuda(), \
               torch.tensor(done_mask_lst).cuda()

    def size(self):
        return len(self.buffer)


def hard_update(target, source):
    """
    Copy network parameters from source to target
    Inputs:
        target (torch.nn.Module): Net to copy parameters to
        source (torch.nn.Module): Net whose parameters to copy
    """
    for target_param, param in zip(target.parameters(), source.parameters()):
        target_param.data.copy_(param.data)


def categorical_sample(probs, use_cuda=False):
    int_acs = torch.multinomial(probs, 1)
    if use_cuda:
        tensor_type = torch.cuda.FloatTensor
    else:
        tensor_type = torch.FloatTensor
    acs = Variable(tensor_type(*probs.shape).fill_(0)).scatter_(1, int_acs, 1)
    return int_acs, acs

def disable_gradients(module):
    for p in module.parameters():
        p.requires_grad = False

def enable_gradients(module):
    for p in module.parameters():
        p.requires_grad = True

class policy(nn.Module):
    def __init__(self):
        super(policy, self).__init__()
        self.fc1 = nn.Linear(np.array(env.observation_space.shape).prod(), 256)
        self.fc2 = nn.Linear(256, 84)
        self.fc3 = nn.Linear(84, env.action_space.n)

    def forward(self, obs, return_all_probs=False):
        # print(self.fc1(obs)[0].shape)
        x = F.leaky_relu(self.fc1(obs))
        x = F.leaky_relu(self.fc2(x))
        out = self.fc3(x)
        probs = F.softmax(out, dim=1)
        on_gpu = next(self.parameters()).is_cuda
        int_act, act = categorical_sample(probs, use_cuda=on_gpu)
        # print(act, int_act)
        rets = [int_act]
        log_probs = F.log_softmax(out, dim=1)
        if return_all_probs:
            rets.append(probs)
        rets.append(log_probs.gather(1, int_act))
        return rets

class SAC(nn.Module):
    def __init__(self):
        super(SAC, self).__init__()
        self.reward_scale = 100.0
        self.policy = policy()
        self.target_policy = policy()

        hard_update(self.target_policy, self.policy)
        input_size = int(np.array(env.observation_space.shape).prod() + np.array(env.action_space.shape).prod())
        # print(input_size)
        self.critic = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.LeakyReLU(inplace=True),
            nn.Linear(256, 84),
            nn.LeakyReLU(inplace=True),
            nn.Linear(84, 1)
        )

        self.target_critic = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.LeakyReLU(inplace=True),
            nn.Linear(256, 84),
            nn.LeakyReLU(inplace=True),
            nn.Linear(84, 1)
        )
        hard_update(self.target_critic, self.critic)
        self.policy_optimizer = optim.Adam(self.policy.parameters(), lr=learning_rate)
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=learning_rate)

    def update_critic(self, memory, soft=True):
        for i in range(4):
            s, a, r, s_prime, done_mask = memory.sample(batch_size)
            # print(s.shape, a.shape)
            a_prime, next_log_pi = self.target_policy(s_prime)
            # print(a_prime.shape, next_log_pi.shape)
            x_prime = torch.cat((s_prime, a_prime), axis=1).cuda()
            x = torch.cat((s, a), axis=1).cuda()
            next_qs = self.target_critic(x_prime)
            q_value = self.critic(x)
            q_loss = 0
            target_q = r.cuda() + gamma * next_qs * done_mask.cuda()
            if soft:
                target_q -= next_log_pi / self.reward_scale
            q_loss += MSELoss(q_value, target_q.detach())

            q_loss.backward()
            self.critic_optimizer.step()
            self.critic_optimizer.zero_grad()



    def update_policy(self, memory, soft=True):
        for i in range(4):
            s, a, r, s_prime, done_mask = memory.sample(batch_size)

            curr_ac, probs, log_pi = self.policy(s, return_all_probs=True)
            all_q = []
            x = torch.cat((s, curr_ac), axis=1).cuda()
            a_list = torch.Tensor(range(18))
            a_new = a_list.expand(s.shape[0], 18).contiguous().view(s.shape[0], 18, 1).transpose(1, 0).cuda()
            s_new = s.expand((18, s.shape[0], s.shape[1])).cuda()
            x_all = torch.cat((s_new, a_new), axis=2).cuda()
            # print(x_all)
            # for j in range(18):
            #     all_q.append(self.critic(x_all[j]).cpu().detach().numpy())
            all_q = self.critic(x_all)
            # print(all_q.shape)

            q = self.critic(x)
            # print(q.shape)
            all_q_ = all_q.transpose(1, 0).squeeze(2).cuda()
            # print(all_q_.shape, probs.shape)
            v = (all_q_ * probs).sum(dim=1, keepdim=True)
            # print(v.shape)
            pol_target = q - v
            if soft:
                pol_loss = (log_pi / self.reward_scale - pol_target).detach().mean()
                pol_loss = Variable(pol_loss, requires_grad=True)
            else:
                pol_loss = -pol_target.detach().mean()
                pol_loss = Variable(pol_loss, requires_grad=True)

            # don't want critic to accumulate gradients from policy loss
            disable_gradients(self.critic)
            pol_loss.backward()
            enable_gradients(self.critic)

            self.policy_optimizer.step()
            self.policy_optimizer.zero_grad()


    def sample_action(self, obs, epsilon):
        # print(obs.shape)
        [out, log] = self.policy(obs)
        return out.item()

# %% [markdown]
# **SAC Train**
#
# ← You can download the videos from the videos folder in the files on the left

# %%
# setup the Gravitar ram environment, and record a video every 50 episodes. You can use the non-ram version here if you prefer、
env = gym.make('Gravitar-ram-v0')
env = gym.wrappers.Monitor(env, "drive/My Drive/rl/video1", video_callable=lambda episode_id: (episode_id%video_every)==0,force=True)

# reproducible environment and action spaces, do not change lines 6-11 here (tools > settings > editor > show line numbers)
seed = 742
torch.manual_seed(seed)
env.seed(seed)
random.seed(seed)
np.random.seed(seed)
env.action_space.seed(seed)
torch.manual_seed(seed)  # cpu
torch.cuda.manual_seed_all(seed)  # gpu
torch.backends.cudnn.deterministic = True  # consistent results on the cpu and gpu
cudnn.benchmark = True  # set to true only if inputs to model are fixed size; otherwise lot of computational overhead
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

q = SAC().to(device)

memory = ReplayBuffer()

score = 0.0
marking = []
optimizer = optim.Adam(q.parameters(), lr=learning_rate)

for n_episode in range(int(1e32)):
    epsilon = 0.06
    s = env.reset()
    # print(len(s))
    done = False
    score = 0.0

    while True:
        # print(torch.from_numpy(s).float().shape)
        a = q.sample_action(torch.from_numpy(s).float().unsqueeze(0).cuda(), epsilon)
        # print(a)
        s_prime, r, done, info = env.step(a)
        done_mask = 0.0 if done else 1.0
        memory.put((s, a, r / 100.0, s_prime, done_mask))
        s = s_prime

        score += r
        if done:
            break

    if memory.size() > 2000:
        # train(q, q_target, memory, optimizer)
        q.update_critic(memory)
        q.update_policy(memory)

    # do not change lines 44-48 here, they are for marking the submission log
    marking.append(score)
    if n_episode % 100 == 0:
        print("marking, episode: {}, score: {:.1f}, mean_score: {:.2f}, std_score: {:.2f}".format(
            n_episode, score, np.array(marking).mean(), np.array(marking).std()))
        logging.basicConfig(level=logging.INFO,
                            filename='gravitar-log1.txt',
                            filemode='a',
                            format='%(message)s')
        # print(len(batch['utilities']))
        logging.info("marking, episode: {}, score: {:.1f}, mean_score: {:.2f}, std_score: {:.2f}".format(
            n_episode, score, np.array(marking).mean(), np.array(marking).std()))
        marking = []

    # you can change this part, and print any data you like (so long as it doesn't start with "marking")
    if n_episode % print_every == 0 and n_episode != 0:
        # q_target.load_state_dict(q.state_dict())
        hard_update(q.target_policy, q.policy)
        hard_update(q.target_critic, q.critic)
        torch.save({'SAC':q.state_dict(), 'policy_optimizer':q.policy_optimizer.state_dict(), 'critic_optimizer':q.critic_optimizer.state_dict()}, 'drive/My Drive/rl/save.chkpt')
        print("episode: {}, score: {:.1f}, epsilon: {:.2f}".format(n_episode, score, epsilon))
# Out:
# marking, episode: 0, score: 700.0, mean_score: 700.00, std_score: 0.00
# episode: 5, score: 0.0, epsilon: 0.06
# episode: 10, score: 350.0, epsilon: 0.06
# episode: 15, score: 0.0, epsilon: 0.06
# episode: 20, score: 0.0, epsilon: 0.06
# episode: 25, score: 450.0, epsilon: 0.06
# episode: 30, score: 0.0, epsilon: 0.06
# episode: 35, score: 250.0, epsilon: 0.06
# episode: 40, score: 0.0, epsilon: 0.06
# episode: 45, score: 0.0, epsilon: 0.06
# episode: 50, score: 0.0, epsilon: 0.06
# episode: 55, score: 100.0, epsilon: 0.06
# episode: 60, score: 600.0, epsilon: 0.06
# episode: 65, score: 450.0, epsilon: 0.06
# episode: 70, score: 250.0, epsilon: 0.06
# episode: 75, score: 0.0, epsilon: 0.06
# episode: 80, score: 0.0, epsilon: 0.06
# episode: 85, score: 100.0, epsilon: 0.06
# episode: 90, score: 600.0, epsilon: 0.06
# episode: 95, score: 0.0, epsilon: 0.06
# marking, episode: 100, score: 600.0, mean_score: 115.00, std_score: 183.51
# episode: 100, score: 600.0, epsilon: 0.06
# episode: 105, score: 0.0, epsilon: 0.06
# episode: 110, score: 0.0, epsilon: 0.06
# episode: 115, score: 100.0, epsilon: 0.06
# episode: 120, score: 600.0, epsilon: 0.06
# episode: 125, score: 0.0, epsilon: 0.06
# episode: 130, score: 100.0, epsilon: 0.06
# episode: 135, score: 0.0, epsilon: 0.06
# episode: 140, score: 0.0, epsilon: 0.06
# episode: 145, score: 0.0, epsilon: 0.06
# episode: 150, score: 0.0, epsilon: 0.06
# episode: 155, score: 0.0, epsilon: 0.06
# episode: 160, score: 0.0, epsilon: 0.06
# episode: 165, score: 0.0, epsilon: 0.06
# episode: 170, score: 0.0, epsilon: 0.06
# episode: 175, score: 0.0, epsilon: 0.06
# episode: 180, score: 500.0, epsilon: 0.06
# episode: 185, score: 100.0, epsilon: 0.06
# episode: 190, score: 0.0, epsilon: 0.06
# episode: 195, score: 0.0, epsilon: 0.06
# marking, episode: 200, score: 0.0, mean_score: 144.00, std_score: 218.09
# episode: 200, score: 0.0, epsilon: 0.06
# episode: 205, score: 0.0, epsilon: 0.06
# episode: 210, score: 0.0, epsilon: 0.06
# episode: 215, score: 0.0, epsilon: 0.06
# episode: 220, score: 0.0, epsilon: 0.06
# episode: 225, score: 0.0, epsilon: 0.06
# episode: 230, score: 450.0, epsilon: 0.06
# episode: 235, score: 850.0, epsilon: 0.06
# episode: 240, score: 0.0, epsilon: 0.06
# episode: 245, score: 0.0, epsilon: 0.06
# episode: 250, score: 0.0, epsilon: 0.06
# episode: 255, score: 0.0, epsilon: 0.06
# episode: 260, score: 100.0, epsilon: 0.06
# episode: 265, score: 100.0, epsilon: 0.06
# episode: 270, score: 100.0, epsilon: 0.06
# episode: 275, score: 0.0, epsilon: 0.06
# episode: 280, score: 0.0, epsilon: 0.06
# episode: 285, score: 0.0, epsilon: 0.06
# episode: 290, score: 0.0, epsilon: 0.06
# episode: 295, score: 500.0, epsilon: 0.06
# marking, episode: 300, score: 0.0, mean_score: 142.00, std_score: 217.11
# episode: 300, score: 0.0, epsilon: 0.06
# episode: 305, score: 0.0, epsilon: 0.06
# episode: 310, score: 500.0, epsilon: 0.06
# episode: 315, score: 350.0, epsilon: 0.06
# episode: 320, score: 0.0, epsilon: 0.06
# episode: 325, score: 250.0, epsilon: 0.06
# episode: 330, score: 450.0, epsilon: 0.06
# episode: 335, score: 100.0, epsilon: 0.06
# episode: 340, score: 0.0, epsilon: 0.06
# episode: 345, score: 250.0, epsilon: 0.06
# episode: 350, score: 500.0, epsilon: 0.06
# episode: 355, score: 750.0, epsilon: 0.06
# episode: 360, score: 350.0, epsilon: 0.06
# episode: 365, score: 100.0, epsilon: 0.06
# episode: 370, score: 250.0, epsilon: 0.06
# episode: 375, score: 600.0, epsilon: 0.06
# episode: 380, score: 350.0, epsilon: 0.06
# episode: 385, score: 0.0, epsilon: 0.06
# episode: 390, score: 0.0, epsilon: 0.06
# episode: 395, score: 700.0, epsilon: 0.06
# marking, episode: 400, score: 100.0, mean_score: 185.50, std_score: 221.05
# episode: 400, score: 100.0, epsilon: 0.06
# episode: 405, score: 0.0, epsilon: 0.06
# episode: 410, score: 0.0, epsilon: 0.06
# episode: 415, score: 100.0, epsilon: 0.06
# episode: 420, score: 250.0, epsilon: 0.06
# episode: 425, score: 950.0, epsilon: 0.06
# episode: 430, score: 250.0, epsilon: 0.06
# episode: 435, score: 250.0, epsilon: 0.06
# episode: 440, score: 0.0, epsilon: 0.06
# episode: 445, score: 550.0, epsilon: 0.06
# episode: 450, score: 0.0, epsilon: 0.06
# episode: 455, score: 100.0, epsilon: 0.06
# episode: 460, score: 0.0, epsilon: 0.06
# episode: 465, score: 0.0, epsilon: 0.06
# episode: 470, score: 0.0, epsilon: 0.06
# episode: 475, score: 850.0, epsilon: 0.06
# episode: 480, score: 550.0, epsilon: 0.06
# episode: 485, score: 250.0, epsilon: 0.06
# episode: 490, score: 0.0, epsilon: 0.06
# episode: 495, score: 0.0, epsilon: 0.06
# marking, episode: 500, score: 0.0, mean_score: 157.00, std_score: 231.95
# episode: 500, score: 0.0, epsilon: 0.06
# episode: 505, score: 0.0, epsilon: 0.06
# episode: 510, score: 0.0, epsilon: 0.06
# episode: 515, score: 500.0, epsilon: 0.06
# episode: 520, score: 0.0, epsilon: 0.06
# episode: 525, score: 0.0, epsilon: 0.06
# episode: 530, score: 0.0, epsilon: 0.06
# episode: 535, score: 0.0, epsilon: 0.06
# episode: 540, score: 0.0, epsilon: 0.06
# episode: 545, score: 0.0, epsilon: 0.06
# episode: 550, score: 100.0, epsilon: 0.06
# episode: 555, score: 0.0, epsilon: 0.06
# episode: 560, score: 250.0, epsilon: 0.06
# episode: 565, score: 0.0, epsilon: 0.06
# episode: 570, score: 250.0, epsilon: 0.06
# episode: 575, score: 0.0, epsilon: 0.06
# episode: 580, score: 100.0, epsilon: 0.06
# episode: 585, score: 250.0, epsilon: 0.06
# episode: 590, score: 0.0, epsilon: 0.06
# episode: 595, score: 0.0, epsilon: 0.06
# marking, episode: 600, score: 0.0, mean_score: 166.00, std_score: 231.94
# episode: 600, score: 0.0, epsilon: 0.06
# episode: 605, score: 100.0, epsilon: 0.06
# episode: 610, score: 0.0, epsilon: 0.06
# episode: 615, score: 100.0, epsilon: 0.06
# episode: 620, score: 100.0, epsilon: 0.06
# episode: 625, score: 0.0, epsilon: 0.06
# episode: 630, score: 0.0, epsilon: 0.06
# episode: 635, score: 250.0, epsilon: 0.06
# episode: 640, score: 0.0, epsilon: 0.06
# episode: 645, score: 200.0, epsilon: 0.06
# episode: 650, score: 100.0, epsilon: 0.06
# episode: 655, score: 250.0, epsilon: 0.06
# episode: 660, score: 0.0, epsilon: 0.06
# episode: 665, score: 500.0, epsilon: 0.06
# episode: 670, score: 100.0, epsilon: 0.06
# episode: 675, score: 100.0, epsilon: 0.06
# episode: 680, score: 0.0, epsilon: 0.06
# episode: 685, score: 0.0, epsilon: 0.06
# episode: 690, score: 0.0, epsilon: 0.06
# episode: 695, score: 0.0, epsilon: 0.06
# marking, episode: 700, score: 0.0, mean_score: 138.50, std_score: 188.66
# episode: 700, score: 0.0, epsilon: 0.06
# episode: 705, score: 0.0, epsilon: 0.06
# episode: 710, score: 0.0, epsilon: 0.06
# episode: 715, score: 0.0, epsilon: 0.06
# episode: 720, score: 0.0, epsilon: 0.06
# episode: 725, score: 0.0, epsilon: 0.06
# episode: 730, score: 0.0, epsilon: 0.06
# episode: 735, score: 0.0, epsilon: 0.06
# episode: 740, score: 0.0, epsilon: 0.06
# episode: 745, score: 0.0, epsilon: 0.06
# episode: 750, score: 0.0, epsilon: 0.06
# episode: 755, score: 0.0, epsilon: 0.06
# episode: 760, score: 0.0, epsilon: 0.06
# episode: 765, score: 250.0, epsilon: 0.06
# episode: 770, score: 0.0, epsilon: 0.06
# episode: 775, score: 0.0, epsilon: 0.06
# episode: 780, score: 0.0, epsilon: 0.06
# episode: 785, score: 350.0, epsilon: 0.06
# episode: 790, score: 0.0, epsilon: 0.06
# episode: 795, score: 500.0, epsilon: 0.06
# marking, episode: 800, score: 0.0, mean_score: 111.00, std_score: 190.21
# episode: 800, score: 0.0, epsilon: 0.06
# episode: 805, score: 0.0, epsilon: 0.06
# episode: 810, score: 0.0, epsilon: 0.06
# episode: 815, score: 100.0, epsilon: 0.06
# episode: 820, score: 0.0, epsilon: 0.06
# episode: 825, score: 0.0, epsilon: 0.06
# episode: 830, score: 0.0, epsilon: 0.06
# episode: 835, score: 250.0, epsilon: 0.06
# episode: 840, score: 0.0, epsilon: 0.06
# episode: 845, score: 100.0, epsilon: 0.06
# episode: 850, score: 0.0, epsilon: 0.06
# episode: 855, score: 0.0, epsilon: 0.06
# episode: 860, score: 0.0, epsilon: 0.06
# episode: 865, score: 700.0, epsilon: 0.06
# episode: 870, score: 0.0, epsilon: 0.06
# episode: 875, score: 0.0, epsilon: 0.06
# episode: 880, score: 0.0, epsilon: 0.06
# episode: 885, score: 500.0, epsilon: 0.06
# episode: 890, score: 0.0, epsilon: 0.06
# episode: 895, score: 350.0, epsilon: 0.06
# marking, episode: 900, score: 100.0, mean_score: 117.00, std_score: 191.08
# episode: 900, score: 100.0, epsilon: 0.06
# episode: 905, score: 0.0, epsilon: 0.06
# episode: 910, score: 100.0, epsilon: 0.06
# episode: 915, score: 100.0, epsilon: 0.06
# episode: 920, score: 0.0, epsilon: 0.06
# episode: 925, score: 500.0, epsilon: 0.06
# episode: 930, score: 350.0, epsilon: 0.06
# episode: 935, score: 0.0, epsilon: 0.06
# episode: 940, score: 100.0, epsilon: 0.06
# episode: 945, score: 0.0, epsilon: 0.06
# episode: 950, score: 0.0, epsilon: 0.06
# episode: 955, score: 100.0, epsilon: 0.06
# episode: 960, score: 600.0, epsilon: 0.06
# episode: 965, score: 0.0, epsilon: 0.06
# episode: 970, score: 0.0, epsilon: 0.06
# episode: 975, score: 0.0, epsilon: 0.06
# episode: 980, score: 0.0, epsilon: 0.06
# episode: 985, score: 100.0, epsilon: 0.06
# episode: 990, score: 0.0, epsilon: 0.06
# episode: 995, score: 0.0, epsilon: 0.06
# marking, episode: 1000, score: 0.0, mean_score: 156.00, std_score: 213.34
# episode: 1000, score: 0.0, epsilon: 0.06
# episode: 1005, score: 0.0, epsilon: 0.06
# episode: 1010, score: 0.0, epsilon: 0.06
# episode: 1015, score: 500.0, epsilon: 0.06
# episode: 1020, score: 0.0, epsilon: 0.06
# episode: 1025, score: 0.0, epsilon: 0.06
# episode: 1030, score: 0.0, epsilon: 0.06
# episode: 1035, score: 0.0, epsilon: 0.06
# episode: 1040, score: 0.0, epsilon: 0.06
# episode: 1045, score: 0.0, epsilon: 0.06
# episode: 1050, score: 0.0, epsilon: 0.06
# episode: 1055, score: 0.0, epsilon: 0.06
# episode: 1060, score: 950.0, epsilon: 0.06
# episode: 1065, score: 350.0, epsilon: 0.06
# episode: 1070, score: 100.0, epsilon: 0.06
# episode: 1075, score: 350.0, epsilon: 0.06
# episode: 1080, score: 0.0, epsilon: 0.06
# episode: 1085, score: 0.0, epsilon: 0.06
# episode: 1090, score: 0.0, epsilon: 0.06
# episode: 1095, score: 0.0, epsilon: 0.06
# marking, episode: 1100, score: 550.0, mean_score: 157.50, std_score: 237.53
# episode: 1100, score: 550.0, epsilon: 0.06
# episode: 1105, score: 100.0, epsilon: 0.06
# episode: 1110, score: 0.0, epsilon: 0.06
# episode: 1115, score: 0.0, epsilon: 0.06
# episode: 1120, score: 200.0, epsilon: 0.06
# episode: 1125, score: 0.0, epsilon: 0.06
# episode: 1130, score: 0.0, epsilon: 0.06
# episode: 1135, score: 100.0, epsilon: 0.06
# episode: 1140, score: 0.0, epsilon: 0.06
# episode: 1145, score: 350.0, epsilon: 0.06
# episode: 1150, score: 500.0, epsilon: 0.06
# episode: 1155, score: 0.0, epsilon: 0.06
# episode: 1160, score: 0.0, epsilon: 0.06
# episode: 1165, score: 0.0, epsilon: 0.06
# episode: 1170, score: 0.0, epsilon: 0.06
# episode: 1175, score: 0.0, epsilon: 0.06
# episode: 1180, score: 100.0, epsilon: 0.06
# episode: 1185, score: 0.0, epsilon: 0.06
# episode: 1190, score: 100.0, epsilon: 0.06
# episode: 1195, score: 0.0, epsilon: 0.06
# marking, episode: 1200, score: 0.0, mean_score: 121.00, std_score: 192.38
# episode: 1200, score: 0.0, epsilon: 0.06
# episode: 1205, score: 0.0, epsilon: 0.06
# episode: 1210, score: 500.0, epsilon: 0.06
# episode: 1215, score: 0.0, epsilon: 0.06
# episode: 1220, score: 350.0, epsilon: 0.06
# episode: 1225, score: 100.0, epsilon: 0.06
# episode: 1230, score: 250.0, epsilon: 0.06
# episode: 1235, score: 0.0, epsilon: 0.06
# episode: 1240, score: 0.0, epsilon: 0.06
# episode: 1245, score: 0.0, epsilon: 0.06
# episode: 1250, score: 350.0, epsilon: 0.06
# episode: 1255, score: 0.0, epsilon: 0.06
# episode: 1260, score: 0.0, epsilon: 0.06
# episode: 1265, score: 200.0, epsilon: 0.06
# episode: 1270, score: 0.0, epsilon: 0.06
# episode: 1275, score: 100.0, epsilon: 0.06
# episode: 1280, score: 0.0, epsilon: 0.06
# episode: 1285, score: 100.0, epsilon: 0.06
# episode: 1290, score: 0.0, epsilon: 0.06
# episode: 1295, score: 100.0, epsilon: 0.06
# marking, episode: 1300, score: 250.0, mean_score: 180.50, std_score: 222.81
# episode: 1300, score: 250.0, epsilon: 0.06
# episode: 1305, score: 0.0, epsilon: 0.06
# episode: 1310, score: 600.0, epsilon: 0.06
# episode: 1315, score: 500.0, epsilon: 0.06
# episode: 1320, score: 350.0, epsilon: 0.06
# episode: 1325, score: 0.0, epsilon: 0.06
# episode: 1330, score: 350.0, epsilon: 0.06
# episode: 1335, score: 0.0, epsilon: 0.06
# episode: 1340, score: 100.0, epsilon: 0.06
# episode: 1345, score: 100.0, epsilon: 0.06
# episode: 1350, score: 0.0, epsilon: 0.06
# episode: 1355, score: 0.0, epsilon: 0.06
# episode: 1360, score: 350.0, epsilon: 0.06
# episode: 1365, score: 450.0, epsilon: 0.06
# episode: 1370, score: 0.0, epsilon: 0.06
# episode: 1375, score: 450.0, epsilon: 0.06
# episode: 1380, score: 0.0, epsilon: 0.06
# episode: 1385, score: 0.0, epsilon: 0.06
# episode: 1390, score: 0.0, epsilon: 0.06
# episode: 1395, score: 750.0, epsilon: 0.06
# marking, episode: 1400, score: 450.0, mean_score: 189.00, std_score: 236.49
# episode: 1400, score: 450.0, epsilon: 0.06
# episode: 1405, score: 250.0, epsilon: 0.06
# episode: 1410, score: 100.0, epsilon: 0.06
# episode: 1415, score: 0.0, epsilon: 0.06
# episode: 1420, score: 250.0, epsilon: 0.06
# episode: 1425, score: 0.0, epsilon: 0.06
# episode: 1430, score: 0.0, epsilon: 0.06
# episode: 1435, score: 0.0, epsilon: 0.06
# episode: 1440, score: 450.0, epsilon: 0.06
# episode: 1445, score: 0.0, epsilon: 0.06
# episode: 1450, score: 200.0, epsilon: 0.06
# episode: 1455, score: 0.0, epsilon: 0.06
# episode: 1460, score: 350.0, epsilon: 0.06
# episode: 1465, score: 250.0, epsilon: 0.06
# episode: 1470, score: 0.0, epsilon: 0.06
# episode: 1475, score: 0.0, epsilon: 0.06
# episode: 1480, score: 0.0, epsilon: 0.06
# episode: 1485, score: 100.0, epsilon: 0.06
# episode: 1490, score: 0.0, epsilon: 0.06
# episode: 1495, score: 0.0, epsilon: 0.06
# marking, episode: 1500, score: 250.0, mean_score: 189.50, std_score: 233.27
# episode: 1500, score: 250.0, epsilon: 0.06
# episode: 1505, score: 100.0, epsilon: 0.06
# episode: 1510, score: 0.0, epsilon: 0.06
# episode: 1515, score: 0.0, epsilon: 0.06
# episode: 1520, score: 500.0, epsilon: 0.06
# episode: 1525, score: 350.0, epsilon: 0.06
# episode: 1530, score: 100.0, epsilon: 0.06
# episode: 1535, score: 250.0, epsilon: 0.06
# episode: 1540, score: 0.0, epsilon: 0.06
# episode: 1545, score: 500.0, epsilon: 0.06
# episode: 1550, score: 0.0, epsilon: 0.06
# episode: 1555, score: 100.0, epsilon: 0.06
# episode: 1560, score: 500.0, epsilon: 0.06
# episode: 1565, score: 0.0, epsilon: 0.06
# episode: 1570, score: 500.0, epsilon: 0.06
# episode: 1575, score: 0.0, epsilon: 0.06
# episode: 1580, score: 350.0, epsilon: 0.06
# episode: 1585, score: 0.0, epsilon: 0.06
# episode: 1590, score: 450.0, epsilon: 0.06
# episode: 1595, score: 0.0, epsilon: 0.06
# marking, episode: 1600, score: 0.0, mean_score: 141.50, std_score: 220.69
# episode: 1600, score: 0.0, epsilon: 0.06
# episode: 1605, score: 100.0, epsilon: 0.06
# episode: 1610, score: 0.0, epsilon: 0.06
# episode: 1615, score: 0.0, epsilon: 0.06
# episode: 1620, score: 100.0, epsilon: 0.06
# episode: 1625, score: 100.0, epsilon: 0.06
# episode: 1630, score: 0.0, epsilon: 0.06
# episode: 1635, score: 350.0, epsilon: 0.06
# episode: 1640, score: 0.0, epsilon: 0.06
# episode: 1645, score: 0.0, epsilon: 0.06
# episode: 1650, score: 0.0, epsilon: 0.06
# episode: 1655, score: 0.0, epsilon: 0.06
# episode: 1660, score: 0.0, epsilon: 0.06
# episode: 1665, score: 0.0, epsilon: 0.06
# episode: 1670, score: 0.0, epsilon: 0.06
# episode: 1675, score: 500.0, epsilon: 0.06
# episode: 1680, score: 0.0, epsilon: 0.06
# episode: 1685, score: 600.0, epsilon: 0.06
# episode: 1690, score: 0.0, epsilon: 0.06
# episode: 1695, score: 0.0, epsilon: 0.06
# marking, episode: 1700, score: 250.0, mean_score: 144.50, std_score: 207.11
# episode: 1700, score: 250.0, epsilon: 0.06
# episode: 1705, score: 350.0, epsilon: 0.06
# episode: 1710, score: 100.0, epsilon: 0.06
# episode: 1715, score: 250.0, epsilon: 0.06
# episode: 1720, score: 0.0, epsilon: 0.06
# episode: 1725, score: 0.0, epsilon: 0.06
# episode: 1730, score: 250.0, epsilon: 0.06
# episode: 1735, score: 500.0, epsilon: 0.06
# episode: 1740, score: 600.0, epsilon: 0.06
# episode: 1745, score: 0.0, epsilon: 0.06
# episode: 1750, score: 100.0, epsilon: 0.06
# episode: 1755, score: 0.0, epsilon: 0.06
# episode: 1760, score: 500.0, epsilon: 0.06
# episode: 1765, score: 500.0, epsilon: 0.06
# episode: 1770, score: 0.0, epsilon: 0.06
# episode: 1775, score: 0.0, epsilon: 0.06
# episode: 1780, score: 0.0, epsilon: 0.06
# episode: 1785, score: 0.0, epsilon: 0.06
# episode: 1790, score: 0.0, epsilon: 0.06
# episode: 1795, score: 600.0, epsilon: 0.06
# marking, episode: 1800, score: 100.0, mean_score: 137.50, std_score: 201.17
# episode: 1800, score: 100.0, epsilon: 0.06
# episode: 1805, score: 600.0, epsilon: 0.06
# episode: 1810, score: 0.0, epsilon: 0.06
# episode: 1815, score: 700.0, epsilon: 0.06
# episode: 1820, score: 100.0, epsilon: 0.06
# episode: 1825, score: 0.0, epsilon: 0.06
# episode: 1830, score: 200.0, epsilon: 0.06
# episode: 1835, score: 0.0, epsilon: 0.06
# episode: 1840, score: 500.0, epsilon: 0.06
# episode: 1845, score: 500.0, epsilon: 0.06
# episode: 1850, score: 0.0, epsilon: 0.06
# episode: 1855, score: 0.0, epsilon: 0.06
# episode: 1860, score: 0.0, epsilon: 0.06
# episode: 1865, score: 100.0, epsilon: 0.06
# episode: 1870, score: 250.0, epsilon: 0.06
# episode: 1875, score: 0.0, epsilon: 0.06
# episode: 1880, score: 0.0, epsilon: 0.06
# episode: 1885, score: 0.0, epsilon: 0.06
# episode: 1890, score: 0.0, epsilon: 0.06
# episode: 1895, score: 0.0, epsilon: 0.06
# marking, episode: 1900, score: 0.0, mean_score: 169.50, std_score: 235.68
# episode: 1900, score: 0.0, epsilon: 0.06
# episode: 1905, score: 0.0, epsilon: 0.06
# episode: 1910, score: 0.0, epsilon: 0.06
# episode: 1915, score: 250.0, epsilon: 0.06
# episode: 1920, score: 0.0, epsilon: 0.06
# episode: 1925, score: 100.0, epsilon: 0.06
# episode: 1930, score: 450.0, epsilon: 0.06
# episode: 1935, score: 0.0, epsilon: 0.06
# episode: 1940, score: 200.0, epsilon: 0.06
# episode: 1945, score: 0.0, epsilon: 0.06
# episode: 1950, score: 250.0, epsilon: 0.06
# episode: 1955, score: 0.0, epsilon: 0.06
# episode: 1960, score: 350.0, epsilon: 0.06
# episode: 1965, score: 0.0, epsilon: 0.06
# episode: 1970, score: 0.0, epsilon: 0.06
# episode: 1975, score: 0.0, epsilon: 0.06
# episode: 1980, score: 0.0, epsilon: 0.06
# episode: 1985, score: 0.0, epsilon: 0.06
# episode: 1990, score: 0.0, epsilon: 0.06
# episode: 1995, score: 450.0, epsilon: 0.06
# marking, episode: 2000, score: 0.0, mean_score: 131.50, std_score: 276.83
# episode: 2000, score: 0.0, epsilon: 0.06
# episode: 2005, score: 0.0, epsilon: 0.06
# episode: 2010, score: 0.0, epsilon: 0.06
# episode: 2015, score: 100.0, epsilon: 0.06
# episode: 2020, score: 0.0, epsilon: 0.06
# episode: 2025, score: 0.0, epsilon: 0.06
# episode: 2030, score: 100.0, epsilon: 0.06
# episode: 2035, score: 0.0, epsilon: 0.06
# episode: 2040, score: 0.0, epsilon: 0.06
# episode: 2045, score: 350.0, epsilon: 0.06
# episode: 2050, score: 750.0, epsilon: 0.06
# episode: 2055, score: 250.0, epsilon: 0.06
# episode: 2060, score: 350.0, epsilon: 0.06
# episode: 2065, score: 100.0, epsilon: 0.06
# episode: 2070, score: 0.0, epsilon: 0.06
# episode: 2075, score: 500.0, epsilon: 0.06
# episode: 2080, score: 600.0, epsilon: 0.06
# episode: 2085, score: 0.0, epsilon: 0.06
# episode: 2090, score: 350.0, epsilon: 0.06
# episode: 2095, score: 350.0, epsilon: 0.06
# marking, episode: 2100, score: 0.0, mean_score: 181.00, std_score: 217.12
# episode: 2100, score: 0.0, epsilon: 0.06
# episode: 2105, score: 100.0, epsilon: 0.06
# episode: 2110, score: 600.0, epsilon: 0.06
# episode: 2115, score: 0.0, epsilon: 0.06
# episode: 2120, score: 100.0, epsilon: 0.06
# episode: 2125, score: 0.0, epsilon: 0.06
# episode: 2130, score: 600.0, epsilon: 0.06
# episode: 2135, score: 350.0, epsilon: 0.06
# episode: 2140, score: 250.0, epsilon: 0.06
# episode: 2145, score: 100.0, epsilon: 0.06
# episode: 2150, score: 0.0, epsilon: 0.06
# episode: 2155, score: 500.0, epsilon: 0.06
# episode: 2160, score: 450.0, epsilon: 0.06
# episode: 2165, score: 0.0, epsilon: 0.06
# episode: 2170, score: 0.0, epsilon: 0.06
# episode: 2175, score: 0.0, epsilon: 0.06
# episode: 2180, score: 350.0, epsilon: 0.06
# episode: 2185, score: 0.0, epsilon: 0.06
# episode: 2190, score: 850.0, epsilon: 0.06
# episode: 2195, score: 0.0, epsilon: 0.06
# marking, episode: 2200, score: 0.0, mean_score: 167.50, std_score: 235.94
# episode: 2200, score: 0.0, epsilon: 0.06
# episode: 2205, score: 600.0, epsilon: 0.06
# episode: 2210, score: 500.0, epsilon: 0.06
# episode: 2215, score: 500.0, epsilon: 0.06
# episode: 2220, score: 250.0, epsilon: 0.06
# episode: 2225, score: 0.0, epsilon: 0.06
# episode: 2230, score: 0.0, epsilon: 0.06
# episode: 2235, score: 0.0, epsilon: 0.06
# episode: 2240, score: 0.0, epsilon: 0.06
# episode: 2245, score: 850.0, epsilon: 0.06
# episode: 2250, score: 0.0, epsilon: 0.06
# episode: 2255, score: 0.0, epsilon: 0.06
# episode: 2260, score: 100.0, epsilon: 0.06
# episode: 2265, score: 0.0, epsilon: 0.06
# episode: 2270, score: 0.0, epsilon: 0.06
# episode: 2275, score: 700.0, epsilon: 0.06
# episode: 2280, score: 0.0, epsilon: 0.06
# episode: 2285, score: 550.0, epsilon: 0.06
# episode: 2290, score: 0.0, epsilon: 0.06
# episode: 2295, score: 0.0, epsilon: 0.06
# marking, episode: 2300, score: 0.0, mean_score: 143.50, std_score: 221.88
# episode: 2300, score: 0.0, epsilon: 0.06
# episode: 2305, score: 0.0, epsilon: 0.06
# episode: 2310, score: 0.0, epsilon: 0.06
# episode: 2315, score: 450.0, epsilon: 0.06
# episode: 2320, score: 0.0, epsilon: 0.06
# episode: 2325, score: 0.0, epsilon: 0.06
# episode: 2330, score: 0.0, epsilon: 0.06
# episode: 2335, score: 250.0, epsilon: 0.06
# episode: 2340, score: 0.0, epsilon: 0.06
# episode: 2345, score: 0.0, epsilon: 0.06
# episode: 2350, score: 0.0, epsilon: 0.06
# episode: 2355, score: 750.0, epsilon: 0.06
# episode: 2360, score: 0.0, epsilon: 0.06
# episode: 2365, score: 100.0, epsilon: 0.06
# episode: 2370, score: 350.0, epsilon: 0.06
# episode: 2375, score: 100.0, epsilon: 0.06
# episode: 2380, score: 0.0, epsilon: 0.06
# episode: 2385, score: 600.0, epsilon: 0.06
# episode: 2390, score: 600.0, epsilon: 0.06
# episode: 2395, score: 750.0, epsilon: 0.06
# marking, episode: 2400, score: 0.0, mean_score: 138.00, std_score: 217.50
# episode: 2400, score: 0.0, epsilon: 0.06
# episode: 2405, score: 0.0, epsilon: 0.06
# episode: 2410, score: 0.0, epsilon: 0.06
# episode: 2415, score: 0.0, epsilon: 0.06
# episode: 2420, score: 0.0, epsilon: 0.06
# episode: 2425, score: 0.0, epsilon: 0.06
# episode: 2430, score: 100.0, epsilon: 0.06
# episode: 2435, score: 0.0, epsilon: 0.06
# episode: 2440, score: 0.0, epsilon: 0.06
# episode: 2445, score: 0.0, epsilon: 0.06
# episode: 2450, score: 0.0, epsilon: 0.06
# episode: 2455, score: 0.0, epsilon: 0.06
# episode: 2460, score: 250.0, epsilon: 0.06
# episode: 2465, score: 500.0, epsilon: 0.06
# episode: 2470, score: 0.0, epsilon: 0.06
# episode: 2475, score: 0.0, epsilon: 0.06
# episode: 2480, score: 0.0, epsilon: 0.06
# episode: 2485, score: 600.0, epsilon: 0.06
# episode: 2490, score: 350.0, epsilon: 0.06
# episode: 2495, score: 0.0, epsilon: 0.06
# marking, episode: 2500, score: 900.0, mean_score: 148.00, std_score: 218.28
# episode: 2500, score: 900.0, epsilon: 0.06
# episode: 2505, score: 100.0, epsilon: 0.06
# episode: 2510, score: 700.0, epsilon: 0.06
# episode: 2515, score: 0.0, epsilon: 0.06
# episode: 2520, score: 0.0, epsilon: 0.06
# episode: 2525, score: 0.0, epsilon: 0.06
# episode: 2530, score: 950.0, epsilon: 0.06
# episode: 2535, score: 0.0, epsilon: 0.06
# episode: 2540, score: 0.0, epsilon: 0.06
# episode: 2545, score: 350.0, epsilon: 0.06
# episode: 2550, score: 0.0, epsilon: 0.06
# episode: 2555, score: 0.0, epsilon: 0.06
# episode: 2560, score: 0.0, epsilon: 0.06
# episode: 2565, score: 500.0, epsilon: 0.06
# episode: 2570, score: 600.0, epsilon: 0.06
# episode: 2575, score: 250.0, epsilon: 0.06
# episode: 2580, score: 0.0, epsilon: 0.06
# episode: 2585, score: 0.0, epsilon: 0.06
# episode: 2590, score: 700.0, epsilon: 0.06
# episode: 2595, score: 0.0, epsilon: 0.06
# marking, episode: 2600, score: 250.0, mean_score: 124.50, std_score: 212.54
# episode: 2600, score: 250.0, epsilon: 0.06
# episode: 2605, score: 0.0, epsilon: 0.06
# episode: 2610, score: 0.0, epsilon: 0.06
# episode: 2615, score: 750.0, epsilon: 0.06
# episode: 2620, score: 450.0, epsilon: 0.06
# episode: 2625, score: 750.0, epsilon: 0.06
# episode: 2630, score: 0.0, epsilon: 0.06
# episode: 2635, score: 250.0, epsilon: 0.06
# episode: 2640, score: 250.0, epsilon: 0.06
# episode: 2645, score: 0.0, epsilon: 0.06
# episode: 2650, score: 0.0, epsilon: 0.06
# episode: 2655, score: 250.0, epsilon: 0.06
# episode: 2660, score: 0.0, epsilon: 0.06
# episode: 2665, score: 250.0, epsilon: 0.06
# episode: 2670, score: 0.0, epsilon: 0.06
# episode: 2675, score: 450.0, epsilon: 0.06
# episode: 2680, score: 250.0, epsilon: 0.06
# episode: 2685, score: 0.0, epsilon: 0.06
# episode: 2690, score: 100.0, epsilon: 0.06
# episode: 2695, score: 250.0, epsilon: 0.06
# marking, episode: 2700, score: 850.0, mean_score: 153.00, std_score: 224.92
# episode: 2700, score: 850.0, epsilon: 0.06
# episode: 2705, score: 0.0, epsilon: 0.06
# episode: 2710, score: 0.0, epsilon: 0.06
# episode: 2715, score: 100.0, epsilon: 0.06
# episode: 2720, score: 100.0, epsilon: 0.06
# episode: 2725, score: 750.0, epsilon: 0.06
# episode: 2730, score: 750.0, epsilon: 0.06
# episode: 2735, score: 0.0, epsilon: 0.06
# episode: 2740, score: 100.0, epsilon: 0.06
# episode: 2745, score: 0.0, epsilon: 0.06
# episode: 2750, score: 0.0, epsilon: 0.06
# episode: 2755, score: 0.0, epsilon: 0.06
# episode: 2760, score: 700.0, epsilon: 0.06
# episode: 2765, score: 0.0, epsilon: 0.06
# episode: 2770, score: 500.0, epsilon: 0.06
# episode: 2775, score: 0.0, epsilon: 0.06
# episode: 2780, score: 0.0, epsilon: 0.06
# episode: 2785, score: 450.0, epsilon: 0.06
# episode: 2790, score: 0.0, epsilon: 0.06
# episode: 2795, score: 0.0, epsilon: 0.06
# marking, episode: 2800, score: 0.0, mean_score: 177.00, std_score: 247.02
# episode: 2800, score: 0.0, epsilon: 0.06
# episode: 2805, score: 0.0, epsilon: 0.06
# episode: 2810, score: 0.0, epsilon: 0.06
# episode: 2815, score: 0.0, epsilon: 0.06
# episode: 2820, score: 500.0, epsilon: 0.06
# episode: 2825, score: 0.0, epsilon: 0.06
# episode: 2830, score: 950.0, epsilon: 0.06
# episode: 2835, score: 100.0, epsilon: 0.06
# episode: 2840, score: 0.0, epsilon: 0.06
# episode: 2845, score: 100.0, epsilon: 0.06
# episode: 2850, score: 0.0, epsilon: 0.06
# episode: 2855, score: 100.0, epsilon: 0.06
# episode: 2860, score: 0.0, epsilon: 0.06
# episode: 2865, score: 100.0, epsilon: 0.06
# episode: 2870, score: 0.0, epsilon: 0.06
# episode: 2875, score: 0.0, epsilon: 0.06
# episode: 2880, score: 0.0, epsilon: 0.06
# episode: 2885, score: 250.0, epsilon: 0.06
# episode: 2890, score: 0.0, epsilon: 0.06
# episode: 2895, score: 0.0, epsilon: 0.06
# marking, episode: 2900, score: 700.0, mean_score: 149.50, std_score: 238.69
# episode: 2900, score: 700.0, epsilon: 0.06
# episode: 2905, score: 0.0, epsilon: 0.06
# episode: 2910, score: 500.0, epsilon: 0.06
# episode: 2915, score: 200.0, epsilon: 0.06
# episode: 2920, score: 0.0, epsilon: 0.06
# episode: 2925, score: 0.0, epsilon: 0.06
# episode: 2930, score: 250.0, epsilon: 0.06
# episode: 2935, score: 0.0, epsilon: 0.06
# episode: 2940, score: 0.0, epsilon: 0.06
# episode: 2945, score: 100.0, epsilon: 0.06
# episode: 2950, score: 0.0, epsilon: 0.06
# episode: 2955, score: 0.0, epsilon: 0.06
# episode: 2960, score: 0.0, epsilon: 0.06
# episode: 2965, score: 100.0, epsilon: 0.06
# episode: 2970, score: 0.0, epsilon: 0.06
# episode: 2975, score: 0.0, epsilon: 0.06
# episode: 2980, score: 0.0, epsilon: 0.06
# episode: 2985, score: 0.0, epsilon: 0.06
# episode: 2990, score: 500.0, epsilon: 0.06
# episode: 2995, score: 0.0, epsilon: 0.06
# marking, episode: 3000, score: 500.0, mean_score: 124.00, std_score: 199.06
# episode: 3000, score: 500.0, epsilon: 0.06
# episode: 3005, score: 350.0, epsilon: 0.06
# episode: 3010, score: 100.0, epsilon: 0.06
# episode: 3015, score: 250.0, epsilon: 0.06
# episode: 3020, score: 450.0, epsilon: 0.06
# episode: 3025, score: 600.0, epsilon: 0.06
# episode: 3030, score: 0.0, epsilon: 0.06
# episode: 3035, score: 500.0, epsilon: 0.06
# episode: 3040, score: 0.0, epsilon: 0.06
# episode: 3045, score: 0.0, epsilon: 0.06
# episode: 3050, score: 0.0, epsilon: 0.06
# episode: 3055, score: 0.0, epsilon: 0.06
# episode: 3060, score: 250.0, epsilon: 0.06
# episode: 3065, score: 0.0, epsilon: 0.06
# episode: 3070, score: 0.0, epsilon: 0.06
# episode: 3075, score: 0.0, epsilon: 0.06
# episode: 3080, score: 0.0, epsilon: 0.06
# episode: 3085, score: 350.0, epsilon: 0.06
# episode: 3090, score: 100.0, epsilon: 0.06
# episode: 3095, score: 0.0, epsilon: 0.06
# marking, episode: 3100, score: 0.0, mean_score: 123.00, std_score: 197.79
# episode: 3100, score: 0.0, epsilon: 0.06
# episode: 3105, score: 100.0, epsilon: 0.06
# episode: 3110, score: 600.0, epsilon: 0.06
# episode: 3115, score: 350.0, epsilon: 0.06
# episode: 3120, score: 0.0, epsilon: 0.06
# episode: 3125, score: 100.0, epsilon: 0.06
# episode: 3130, score: 900.0, epsilon: 0.06
# episode: 3135, score: 0.0, epsilon: 0.06
# episode: 3140, score: 0.0, epsilon: 0.06
# episode: 3145, score: 0.0, epsilon: 0.06
# episode: 3150, score: 700.0, epsilon: 0.06
# episode: 3155, score: 100.0, epsilon: 0.06
# episode: 3160, score: 0.0, epsilon: 0.06
# episode: 3165, score: 0.0, epsilon: 0.06
# episode: 3170, score: 0.0, epsilon: 0.06
# episode: 3175, score: 0.0, epsilon: 0.06
# episode: 3180, score: 0.0, epsilon: 0.06
# episode: 3185, score: 0.0, epsilon: 0.06
# episode: 3190, score: 500.0, epsilon: 0.06
# episode: 3195, score: 0.0, epsilon: 0.06
# marking, episode: 3200, score: 0.0, mean_score: 121.00, std_score: 210.97
# episode: 3200, score: 0.0, epsilon: 0.06
# episode: 3205, score: 0.0, epsilon: 0.06
# episode: 3210, score: 250.0, epsilon: 0.06
# episode: 3215, score: 100.0, epsilon: 0.06
# episode: 3220, score: 0.0, epsilon: 0.06
# episode: 3225, score: 250.0, epsilon: 0.06
# episode: 3230, score: 0.0, epsilon: 0.06
# episode: 3235, score: 0.0, epsilon: 0.06
# episode: 3240, score: 0.0, epsilon: 0.06
# episode: 3245, score: 0.0, epsilon: 0.06
# episode: 3250, score: 0.0, epsilon: 0.06
# episode: 3255, score: 450.0, epsilon: 0.06
# episode: 3260, score: 0.0, epsilon: 0.06
# episode: 3265, score: 0.0, epsilon: 0.06
# episode: 3270, score: 100.0, epsilon: 0.06
# episode: 3275, score: 200.0, epsilon: 0.06
# episode: 3280, score: 250.0, epsilon: 0.06
# episode: 3285, score: 0.0, epsilon: 0.06
# episode: 3290, score: 0.0, epsilon: 0.06
# episode: 3295, score: 100.0, epsilon: 0.06
# marking, episode: 3300, score: 100.0, mean_score: 107.50, std_score: 180.19
# episode: 3300, score: 100.0, epsilon: 0.06
# episode: 3305, score: 0.0, epsilon: 0.06
# episode: 3310, score: 0.0, epsilon: 0.06
# episode: 3315, score: 0.0, epsilon: 0.06
# episode: 3320, score: 100.0, epsilon: 0.06
# episode: 3325, score: 0.0, epsilon: 0.06
# episode: 3330, score: 0.0, epsilon: 0.06
# episode: 3335, score: 250.0, epsilon: 0.06
# episode: 3340, score: 100.0, epsilon: 0.06
# episode: 3345, score: 450.0, epsilon: 0.06
# episode: 3350, score: 100.0, epsilon: 0.06
# episode: 3355, score: 0.0, epsilon: 0.06
# episode: 3360, score: 100.0, epsilon: 0.06
# episode: 3365, score: 300.0, epsilon: 0.06
# episode: 3370, score: 0.0, epsilon: 0.06
# episode: 3375, score: 0.0, epsilon: 0.06
# episode: 3380, score: 0.0, epsilon: 0.06
# episode: 3385, score: 0.0, epsilon: 0.06
# episode: 3390, score: 0.0, epsilon: 0.06
# episode: 3395, score: 0.0, epsilon: 0.06
# marking, episode: 3400, score: 600.0, mean_score: 98.50, std_score: 156.60
# episode: 3400, score: 600.0, epsilon: 0.06
# episode: 3405, score: 0.0, epsilon: 0.06
# episode: 3410, score: 0.0, epsilon: 0.06
# episode: 3415, score: 0.0, epsilon: 0.06
# episode: 3420, score: 0.0, epsilon: 0.06
# episode: 3425, score: 0.0, epsilon: 0.06
# episode: 3430, score: 0.0, epsilon: 0.06
# episode: 3435, score: 0.0, epsilon: 0.06
# episode: 3440, score: 0.0, epsilon: 0.06
# episode: 3445, score: 0.0, epsilon: 0.06
# episode: 3450, score: 0.0, epsilon: 0.06
# episode: 3455, score: 0.0, epsilon: 0.06
# episode: 3460, score: 0.0, epsilon: 0.06
# episode: 3465, score: 0.0, epsilon: 0.06
# episode: 3470, score: 0.0, epsilon: 0.06
# episode: 3475, score: 0.0, epsilon: 0.06
# episode: 3480, score: 0.0, epsilon: 0.06
# episode: 3485, score: 0.0, epsilon: 0.06
# episode: 3490, score: 100.0, epsilon: 0.06
# episode: 3495, score: 0.0, epsilon: 0.06
# marking, episode: 3500, score: 0.0, mean_score: 91.50, std_score: 177.91
# episode: 3500, score: 0.0, epsilon: 0.06
# episode: 3505, score: 250.0, epsilon: 0.06
# episode: 3510, score: 500.0, epsilon: 0.06
# episode: 3515, score: 100.0, epsilon: 0.06
# episode: 3520, score: 0.0, epsilon: 0.06
# episode: 3525, score: 0.0, epsilon: 0.06
# episode: 3530, score: 0.0, epsilon: 0.06
# episode: 3535, score: 0.0, epsilon: 0.06
# episode: 3540, score: 0.0, epsilon: 0.06
# episode: 3545, score: 0.0, epsilon: 0.06
# episode: 3550, score: 0.0, epsilon: 0.06
# episode: 3555, score: 200.0, epsilon: 0.06
# episode: 3560, score: 0.0, epsilon: 0.06
# episode: 3565, score: 0.0, epsilon: 0.06
# episode: 3570, score: 0.0, epsilon: 0.06
# episode: 3575, score: 750.0, epsilon: 0.06
# episode: 3580, score: 0.0, epsilon: 0.06
# episode: 3585, score: 500.0, epsilon: 0.06
# episode: 3590, score: 0.0, epsilon: 0.06
# episode: 3595, score: 0.0, epsilon: 0.06
# marking, episode: 3600, score: 0.0, mean_score: 141.50, std_score: 219.67
# episode: 3600, score: 0.0, epsilon: 0.06
# episode: 3605, score: 0.0, epsilon: 0.06
# episode: 3610, score: 100.0, epsilon: 0.06
# episode: 3615, score: 0.0, epsilon: 0.06
# episode: 3620, score: 250.0, epsilon: 0.06
# episode: 3625, score: 0.0, epsilon: 0.06
# episode: 3630, score: 450.0, epsilon: 0.06
# episode: 3635, score: 0.0, epsilon: 0.06
# episode: 3640, score: 0.0, epsilon: 0.06
# episode: 3645, score: 0.0, epsilon: 0.06
# episode: 3650, score: 250.0, epsilon: 0.06
# episode: 3655, score: 0.0, epsilon: 0.06
# episode: 3660, score: 100.0, epsilon: 0.06
# episode: 3665, score: 100.0, epsilon: 0.06
# episode: 3670, score: 0.0, epsilon: 0.06
# episode: 3675, score: 250.0, epsilon: 0.06
# episode: 3680, score: 0.0, epsilon: 0.06
# episode: 3685, score: 0.0, epsilon: 0.06
# episode: 3690, score: 0.0, epsilon: 0.06
# episode: 3695, score: 0.0, epsilon: 0.06
# marking, episode: 3700, score: 350.0, mean_score: 111.00, std_score: 180.91
# episode: 3700, score: 350.0, epsilon: 0.06
# episode: 3705, score: 0.0, epsilon: 0.06
# episode: 3710, score: 0.0, epsilon: 0.06
# episode: 3715, score: 0.0, epsilon: 0.06
# episode: 3720, score: 600.0, epsilon: 0.06
# episode: 3725, score: 250.0, epsilon: 0.06
# episode: 3730, score: 0.0, epsilon: 0.06
# episode: 3735, score: 750.0, epsilon: 0.06
# episode: 3740, score: 0.0, epsilon: 0.06
# episode: 3745, score: 250.0, epsilon: 0.06
# episode: 3750, score: 250.0, epsilon: 0.06
# episode: 3755, score: 0.0, epsilon: 0.06
# episode: 3760, score: 350.0, epsilon: 0.06
# episode: 3765, score: 0.0, epsilon: 0.06
# episode: 3770, score: 0.0, epsilon: 0.06
# episode: 3775, score: 500.0, epsilon: 0.06
# episode: 3780, score: 250.0, epsilon: 0.06
# episode: 3785, score: 700.0, epsilon: 0.06
# episode: 3790, score: 0.0, epsilon: 0.06
# episode: 3795, score: 500.0, epsilon: 0.06
# marking, episode: 3800, score: 100.0, mean_score: 171.00, std_score: 239.08
# episode: 3800, score: 100.0, epsilon: 0.06
# episode: 3805, score: 0.0, epsilon: 0.06
# episode: 3810, score: 250.0, epsilon: 0.06
# episode: 3815, score: 0.0, epsilon: 0.06
# episode: 3820, score: 0.0, epsilon: 0.06
# episode: 3825, score: 0.0, epsilon: 0.06
# episode: 3830, score: 0.0, epsilon: 0.06
# episode: 3835, score: 250.0, epsilon: 0.06
# episode: 3840, score: 0.0, epsilon: 0.06
# episode: 3845, score: 0.0, epsilon: 0.06
# episode: 3850, score: 100.0, epsilon: 0.06
# episode: 3855, score: 250.0, epsilon: 0.06
# episode: 3860, score: 250.0, epsilon: 0.06
# episode: 3865, score: 500.0, epsilon: 0.06
# episode: 3870, score: 100.0, epsilon: 0.06
# episode: 3875, score: 0.0, epsilon: 0.06
# episode: 3880, score: 0.0, epsilon: 0.06
# episode: 3885, score: 100.0, epsilon: 0.06
# episode: 3890, score: 350.0, epsilon: 0.06
# episode: 3895, score: 900.0, epsilon: 0.06
# marking, episode: 3900, score: 0.0, mean_score: 127.00, std_score: 188.34
# episode: 3900, score: 0.0, epsilon: 0.06
# episode: 3905, score: 0.0, epsilon: 0.06
# episode: 3910, score: 500.0, epsilon: 0.06
# episode: 3915, score: 250.0, epsilon: 0.06
# episode: 3920, score: 0.0, epsilon: 0.06
# episode: 3925, score: 0.0, epsilon: 0.06
# episode: 3930, score: 0.0, epsilon: 0.06
# episode: 3935, score: 500.0, epsilon: 0.06
# episode: 3940, score: 0.0, epsilon: 0.06
# episode: 3945, score: 250.0, epsilon: 0.06
# episode: 3950, score: 0.0, epsilon: 0.06
# episode: 3955, score: 0.0, epsilon: 0.06
# episode: 3960, score: 0.0, epsilon: 0.06
# episode: 3965, score: 600.0, epsilon: 0.06
# episode: 3970, score: 0.0, epsilon: 0.06
# episode: 3975, score: 0.0, epsilon: 0.06
# episode: 3980, score: 500.0, epsilon: 0.06
# episode: 3985, score: 0.0, epsilon: 0.06
# episode: 3990, score: 0.0, epsilon: 0.06
# episode: 3995, score: 250.0, epsilon: 0.06
# marking, episode: 4000, score: 100.0, mean_score: 164.50, std_score: 250.93
# episode: 4000, score: 100.0, epsilon: 0.06
# episode: 4005, score: 0.0, epsilon: 0.06
# episode: 4010, score: 0.0, epsilon: 0.06
# episode: 4015, score: 350.0, epsilon: 0.06
# episode: 4020, score: 0.0, epsilon: 0.06
# episode: 4025, score: 250.0, epsilon: 0.06
# episode: 4030, score: 0.0, epsilon: 0.06
# episode: 4035, score: 500.0, epsilon: 0.06
# episode: 4040, score: 0.0, epsilon: 0.06
# episode: 4045, score: 0.0, epsilon: 0.06
# episode: 4050, score: 100.0, epsilon: 0.06
# episode: 4055, score: 350.0, epsilon: 0.06
# episode: 4060, score: 0.0, epsilon: 0.06
# episode: 4065, score: 700.0, epsilon: 0.06
# episode: 4070, score: 500.0, epsilon: 0.06
# episode: 4075, score: 500.0, epsilon: 0.06
# episode: 4080, score: 0.0, epsilon: 0.06
# episode: 4085, score: 600.0, epsilon: 0.06
# episode: 4090, score: 0.0, epsilon: 0.06
# episode: 4095, score: 0.0, epsilon: 0.06
# marking, episode: 4100, score: 200.0, mean_score: 133.00, std_score: 207.99
# episode: 4100, score: 200.0, epsilon: 0.06
# episode: 4105, score: 0.0, epsilon: 0.06
# episode: 4110, score: 100.0, epsilon: 0.06
# episode: 4115, score: 0.0, epsilon: 0.06
# episode: 4120, score: 0.0, epsilon: 0.06
# episode: 4125, score: 0.0, epsilon: 0.06
# episode: 4130, score: 100.0, epsilon: 0.06
# episode: 4135, score: 950.0, epsilon: 0.06
# episode: 4140, score: 0.0, epsilon: 0.06
# episode: 4145, score: 0.0, epsilon: 0.06
# episode: 4150, score: 250.0, epsilon: 0.06
# episode: 4155, score: 0.0, epsilon: 0.06
# episode: 4160, score: 250.0, epsilon: 0.06
# episode: 4165, score: 100.0, epsilon: 0.06
# episode: 4170, score: 100.0, epsilon: 0.06
# episode: 4175, score: 0.0, epsilon: 0.06
# episode: 4180, score: 0.0, epsilon: 0.06
# episode: 4185, score: 350.0, epsilon: 0.06
# episode: 4190, score: 0.0, epsilon: 0.06
# episode: 4195, score: 250.0, epsilon: 0.06
# marking, episode: 4200, score: 100.0, mean_score: 156.00, std_score: 240.24
# episode: 4200, score: 100.0, epsilon: 0.06
# episode: 4205, score: 0.0, epsilon: 0.06
# episode: 4210, score: 0.0, epsilon: 0.06
# episode: 4215, score: 0.0, epsilon: 0.06
# episode: 4220, score: 0.0, epsilon: 0.06
# episode: 4225, score: 0.0, epsilon: 0.06
# episode: 4230, score: 0.0, epsilon: 0.06
# episode: 4235, score: 0.0, epsilon: 0.06
# episode: 4240, score: 0.0, epsilon: 0.06
# episode: 4245, score: 0.0, epsilon: 0.06
# episode: 4250, score: 0.0, epsilon: 0.06
# episode: 4255, score: 0.0, epsilon: 0.06
# episode: 4260, score: 0.0, epsilon: 0.06
# episode: 4265, score: 0.0, epsilon: 0.06
# episode: 4270, score: 0.0, epsilon: 0.06
# episode: 4275, score: 0.0, epsilon: 0.06
# episode: 4280, score: 250.0, epsilon: 0.06
# episode: 4285, score: 200.0, epsilon: 0.06
# episode: 4290, score: 350.0, epsilon: 0.06
# episode: 4295, score: 0.0, epsilon: 0.06
# marking, episode: 4300, score: 0.0, mean_score: 116.00, std_score: 187.87
# episode: 4300, score: 0.0, epsilon: 0.06
# episode: 4305, score: 250.0, epsilon: 0.06
# episode: 4310, score: 100.0, epsilon: 0.06
# episode: 4315, score: 100.0, epsilon: 0.06
# episode: 4320, score: 0.0, epsilon: 0.06
# episode: 4325, score: 0.0, epsilon: 0.06
# episode: 4330, score: 0.0, epsilon: 0.06
# episode: 4335, score: 100.0, epsilon: 0.06
# episode: 4340, score: 250.0, epsilon: 0.06
# episode: 4345, score: 450.0, epsilon: 0.06
# episode: 4350, score: 0.0, epsilon: 0.06
# episode: 4355, score: 0.0, epsilon: 0.06
# episode: 4360, score: 350.0, epsilon: 0.06
# episode: 4365, score: 500.0, epsilon: 0.06
# episode: 4370, score: 250.0, epsilon: 0.06
# episode: 4375, score: 250.0, epsilon: 0.06
# episode: 4380, score: 250.0, epsilon: 0.06
# episode: 4385, score: 250.0, epsilon: 0.06
# episode: 4390, score: 600.0, epsilon: 0.06
# episode: 4395, score: 0.0, epsilon: 0.06
# marking, episode: 4400, score: 100.0, mean_score: 145.50, std_score: 200.64
# episode: 4400, score: 100.0, epsilon: 0.06
# episode: 4405, score: 100.0, epsilon: 0.06
# episode: 4410, score: 250.0, epsilon: 0.06
# episode: 4415, score: 250.0, epsilon: 0.06
# episode: 4420, score: 0.0, epsilon: 0.06
# episode: 4425, score: 600.0, epsilon: 0.06
# episode: 4430, score: 0.0, epsilon: 0.06
# episode: 4435, score: 500.0, epsilon: 0.06
# episode: 4440, score: 0.0, epsilon: 0.06
# episode: 4445, score: 0.0, epsilon: 0.06
# episode: 4450, score: 0.0, epsilon: 0.06
# episode: 4455, score: 0.0, epsilon: 0.06
# episode: 4460, score: 0.0, epsilon: 0.06
# episode: 4465, score: 0.0, epsilon: 0.06
# episode: 4470, score: 0.0, epsilon: 0.06
# episode: 4475, score: 0.0, epsilon: 0.06
# episode: 4480, score: 0.0, epsilon: 0.06
# episode: 4485, score: 0.0, epsilon: 0.06
# episode: 4490, score: 0.0, epsilon: 0.06
# episode: 4495, score: 0.0, epsilon: 0.06
# marking, episode: 4500, score: 0.0, mean_score: 129.50, std_score: 201.26
# episode: 4500, score: 0.0, epsilon: 0.06
# episode: 4505, score: 200.0, epsilon: 0.06
# episode: 4510, score: 0.0, epsilon: 0.06
# episode: 4515, score: 0.0, epsilon: 0.06
# episode: 4520, score: 0.0, epsilon: 0.06
# episode: 4525, score: 0.0, epsilon: 0.06
# episode: 4530, score: 0.0, epsilon: 0.06
# episode: 4535, score: 0.0, epsilon: 0.06
# episode: 4540, score: 0.0, epsilon: 0.06
# episode: 4545, score: 500.0, epsilon: 0.06
# episode: 4550, score: 0.0, epsilon: 0.06
# episode: 4555, score: 0.0, epsilon: 0.06
# episode: 4560, score: 0.0, epsilon: 0.06
# episode: 4565, score: 250.0, epsilon: 0.06
# episode: 4570, score: 700.0, epsilon: 0.06
# episode: 4575, score: 850.0, epsilon: 0.06
# episode: 4580, score: 0.0, epsilon: 0.06
# episode: 4585, score: 0.0, epsilon: 0.06
# episode: 4590, score: 0.0, epsilon: 0.06
# episode: 4595, score: 0.0, epsilon: 0.06
# marking, episode: 4600, score: 0.0, mean_score: 152.00, std_score: 233.76
# episode: 4600, score: 0.0, epsilon: 0.06
# episode: 4605, score: 0.0, epsilon: 0.06
# episode: 4610, score: 350.0, epsilon: 0.06
# episode: 4615, score: 450.0, epsilon: 0.06
# episode: 4620, score: 100.0, epsilon: 0.06
# episode: 4625, score: 0.0, epsilon: 0.06
# episode: 4630, score: 0.0, epsilon: 0.06
# episode: 4635, score: 250.0, epsilon: 0.06
# episode: 4640, score: 0.0, epsilon: 0.06
# episode: 4645, score: 0.0, epsilon: 0.06
# episode: 4650, score: 0.0, epsilon: 0.06
# episode: 4655, score: 0.0, epsilon: 0.06
# episode: 4660, score: 100.0, epsilon: 0.06
# episode: 4665, score: 350.0, epsilon: 0.06
# episode: 4670, score: 0.0, epsilon: 0.06
# episode: 4675, score: 0.0, epsilon: 0.06
# episode: 4680, score: 500.0, epsilon: 0.06
# episode: 4685, score: 0.0, epsilon: 0.06
# episode: 4690, score: 100.0, epsilon: 0.06
# episode: 4695, score: 100.0, epsilon: 0.06
# marking, episode: 4700, score: 0.0, mean_score: 127.00, std_score: 184.18
# episode: 4700, score: 0.0, epsilon: 0.06
# episode: 4705, score: 0.0, epsilon: 0.06
# episode: 4710, score: 0.0, epsilon: 0.06
# episode: 4715, score: 0.0, epsilon: 0.06
# episode: 4720, score: 0.0, epsilon: 0.06
# episode: 4725, score: 0.0, epsilon: 0.06
# episode: 4730, score: 500.0, epsilon: 0.06
# episode: 4735, score: 450.0, epsilon: 0.06
# episode: 4740, score: 500.0, epsilon: 0.06
# episode: 4745, score: 0.0, epsilon: 0.06
# episode: 4750, score: 500.0, epsilon: 0.06
# episode: 4755, score: 0.0, epsilon: 0.06
# episode: 4760, score: 250.0, epsilon: 0.06
# episode: 4765, score: 0.0, epsilon: 0.06
# episode: 4770, score: 0.0, epsilon: 0.06
# episode: 4775, score: 100.0, epsilon: 0.06
# episode: 4780, score: 500.0, epsilon: 0.06
# episode: 4785, score: 500.0, epsilon: 0.06
# episode: 4790, score: 0.0, epsilon: 0.06
# episode: 4795, score: 0.0, epsilon: 0.06
# marking, episode: 4800, score: 600.0, mean_score: 122.00, std_score: 189.52
# episode: 4800, score: 600.0, epsilon: 0.06
# episode: 4805, score: 0.0, epsilon: 0.06
# episode: 4810, score: 500.0, epsilon: 0.06
# episode: 4815, score: 100.0, epsilon: 0.06
# episode: 4820, score: 0.0, epsilon: 0.06
# episode: 4825, score: 350.0, epsilon: 0.06
# episode: 4830, score: 0.0, epsilon: 0.06
# episode: 4835, score: 0.0, epsilon: 0.06
# episode: 4840, score: 100.0, epsilon: 0.06
# episode: 4845, score: 100.0, epsilon: 0.06
# episode: 4850, score: 350.0, epsilon: 0.06
# episode: 4855, score: 600.0, epsilon: 0.06
# episode: 4860, score: 350.0, epsilon: 0.06
# episode: 4865, score: 100.0, epsilon: 0.06
# episode: 4870, score: 200.0, epsilon: 0.06
# episode: 4875, score: 200.0, epsilon: 0.06
# episode: 4880, score: 0.0, epsilon: 0.06
# episode: 4885, score: 0.0, epsilon: 0.06
# episode: 4890, score: 0.0, epsilon: 0.06
# episode: 4895, score: 250.0, epsilon: 0.06
# marking, episode: 4900, score: 500.0, mean_score: 170.50, std_score: 221.14
# episode: 4900, score: 500.0, epsilon: 0.06
# episode: 4905, score: 350.0, epsilon: 0.06
# episode: 4910, score: 0.0, epsilon: 0.06
# episode: 4915, score: 0.0, epsilon: 0.06
# episode: 4920, score: 0.0, epsilon: 0.06
# episode: 4925, score: 0.0, epsilon: 0.06
# episode: 4930, score: 250.0, epsilon: 0.06
# episode: 4935, score: 350.0, epsilon: 0.06
# episode: 4940, score: 250.0, epsilon: 0.06
# episode: 4945, score: 0.0, epsilon: 0.06
# episode: 4950, score: 200.0, epsilon: 0.06
# episode: 4955, score: 0.0, epsilon: 0.06
# episode: 4960, score: 500.0, epsilon: 0.06
# episode: 4965, score: 0.0, epsilon: 0.06
# episode: 4970, score: 500.0, epsilon: 0.06
# episode: 4975, score: 0.0, epsilon: 0.06
# episode: 4980, score: 500.0, epsilon: 0.06
# episode: 4985, score: 0.0, epsilon: 0.06
# episode: 4990, score: 450.0, epsilon: 0.06
# episode: 4995, score: 450.0, epsilon: 0.06
# marking, episode: 5000, score: 0.0, mean_score: 139.00, std_score: 184.60
# episode: 5000, score: 0.0, epsilon: 0.06
# episode: 5005, score: 0.0, epsilon: 0.06
# episode: 5010, score: 0.0, epsilon: 0.06
# episode: 5015, score: 750.0, epsilon: 0.06
# episode: 5020, score: 250.0, epsilon: 0.06
# episode: 5025, score: 350.0, epsilon: 0.06
# episode: 5030, score: 500.0, epsilon: 0.06
# episode: 5035, score: 350.0, epsilon: 0.06
# episode: 5040, score: 0.0, epsilon: 0.06
# episode: 5045, score: 0.0, epsilon: 0.06
# episode: 5050, score: 0.0, epsilon: 0.06
# episode: 5055, score: 500.0, epsilon: 0.06
# episode: 5060, score: 500.0, epsilon: 0.06
# episode: 5065, score: 0.0, epsilon: 0.06
# episode: 5070, score: 700.0, epsilon: 0.06
# episode: 5075, score: 0.0, epsilon: 0.06
# episode: 5080, score: 0.0, epsilon: 0.06
# episode: 5085, score: 100.0, epsilon: 0.06
# episode: 5090, score: 700.0, epsilon: 0.06
# episode: 5095, score: 0.0, epsilon: 0.06
# marking, episode: 5100, score: 0.0, mean_score: 167.00, std_score: 241.06
# episode: 5100, score: 0.0, epsilon: 0.06
# episode: 5105, score: 500.0, epsilon: 0.06
# episode: 5110, score: 0.0, epsilon: 0.06
# episode: 5115, score: 250.0, epsilon: 0.06
# episode: 5120, score: 0.0, epsilon: 0.06
# episode: 5125, score: 100.0, epsilon: 0.06
# episode: 5130, score: 350.0, epsilon: 0.06
# episode: 5135, score: 100.0, epsilon: 0.06
# episode: 5140, score: 0.0, epsilon: 0.06
# episode: 5145, score: 100.0, epsilon: 0.06
# episode: 5150, score: 250.0, epsilon: 0.06
# episode: 5155, score: 200.0, epsilon: 0.06
# episode: 5160, score: 100.0, epsilon: 0.06
# episode: 5165, score: 0.0, epsilon: 0.06
# episode: 5170, score: 0.0, epsilon: 0.06
# episode: 5175, score: 100.0, epsilon: 0.06
# episode: 5180, score: 0.0, epsilon: 0.06
# episode: 5185, score: 350.0, epsilon: 0.06
# episode: 5190, score: 0.0, epsilon: 0.06
# episode: 5195, score: 350.0, epsilon: 0.06
# marking, episode: 5200, score: 0.0, mean_score: 128.50, std_score: 196.88
# episode: 5200, score: 0.0, epsilon: 0.06
# episode: 5205, score: 0.0, epsilon: 0.06
# episode: 5210, score: 0.0, epsilon: 0.06
# episode: 5215, score: 0.0, epsilon: 0.06
# episode: 5220, score: 100.0, epsilon: 0.06
# episode: 5225, score: 0.0, epsilon: 0.06
# episode: 5230, score: 0.0, epsilon: 0.06
# episode: 5235, score: 0.0, epsilon: 0.06
# episode: 5240, score: 0.0, epsilon: 0.06
# episode: 5245, score: 0.0, epsilon: 0.06
# episode: 5250, score: 0.0, epsilon: 0.06
# episode: 5255, score: 250.0, epsilon: 0.06
# episode: 5260, score: 0.0, epsilon: 0.06
# episode: 5265, score: 100.0, epsilon: 0.06
# episode: 5270, score: 500.0, epsilon: 0.06
# episode: 5275, score: 100.0, epsilon: 0.06
# episode: 5280, score: 0.0, epsilon: 0.06
# episode: 5285, score: 500.0, epsilon: 0.06
# ...
# episode: 16475, score: 0.0, epsilon: 0.06
# episode: 16480, score: 0.0, epsilon: 0.06
# episode: 16485, score: 0.0, epsilon: 0.06
# episode: 16490, score: 100.0, epsilon: 0.06
# episode: 16495, score: 250.0, epsilon: 0.06
# marking, episode: 16500, score: 0.0, mean_score: 82.50, std_score: 142.19
# episode: 16500, score: 0.0, epsilon: 0.06
# episode: 16505, score: 600.0, epsilon: 0.06
# episode: 16510, score: 0.0, epsilon: 0.06
# episode: 16515, score: 0.0, epsilon: 0.06
# episode: 16520, score: 600.0, epsilon: 0.06
# episode: 16525, score: 0.0, epsilon: 0.06
# episode: 16530, score: 0.0, epsilon: 0.06
# episode: 16535, score: 0.0, epsilon: 0.06
# episode: 16540, score: 0.0, epsilon: 0.06
# episode: 16545, score: 0.0, epsilon: 0.06
# episode: 16550, score: 0.0, epsilon: 0.06
# episode: 16555, score: 0.0, epsilon: 0.06
# episode: 16560, score: 0.0, epsilon: 0.06
# episode: 16565, score: 0.0, epsilon: 0.06
# episode: 16570, score: 0.0, epsilon: 0.06
# episode: 16575, score: 250.0, epsilon: 0.06
# episode: 16580, score: 200.0, epsilon: 0.06
# episode: 16585, score: 0.0, epsilon: 0.06
# episode: 16590, score: 0.0, epsilon: 0.06
# episode: 16595, score: 0.0, epsilon: 0.06
# marking, episode: 16600, score: 0.0, mean_score: 120.50, std_score: 211.32
# episode: 16600, score: 0.0, epsilon: 0.06
# episode: 16605, score: 0.0, epsilon: 0.06
# episode: 16610, score: 600.0, epsilon: 0.06
# episode: 16615, score: 0.0, epsilon: 0.06
# episode: 16620, score: 100.0, epsilon: 0.06
# episode: 16625, score: 0.0, epsilon: 0.06
# episode: 16630, score: 0.0, epsilon: 0.06
# episode: 16635, score: 500.0, epsilon: 0.06
# episode: 16640, score: 350.0, epsilon: 0.06
# episode: 16645, score: 0.0, epsilon: 0.06
# episode: 16650, score: 0.0, epsilon: 0.06
# episode: 16655, score: 0.0, epsilon: 0.06
# episode: 16660, score: 350.0, epsilon: 0.06
# episode: 16665, score: 250.0, epsilon: 0.06
# episode: 16670, score: 250.0, epsilon: 0.06
# episode: 16675, score: 0.0, epsilon: 0.06
# episode: 16680, score: 0.0, epsilon: 0.06
# episode: 16685, score: 0.0, epsilon: 0.06
# episode: 16690, score: 0.0, epsilon: 0.06
# episode: 16695, score: 100.0, epsilon: 0.06
# marking, episode: 16700, score: 750.0, mean_score: 147.50, std_score: 216.61
# episode: 16700, score: 750.0, epsilon: 0.06
# episode: 16705, score: 450.0, epsilon: 0.06
# episode: 16710, score: 0.0, epsilon: 0.06
# episode: 16715, score: 0.0, epsilon: 0.06
# episode: 16720, score: 0.0, epsilon: 0.06
# episode: 16725, score: 0.0, epsilon: 0.06
# episode: 16730, score: 250.0, epsilon: 0.06
# episode: 16735, score: 0.0, epsilon: 0.06
# episode: 16740, score: 0.0, epsilon: 0.06
# episode: 16745, score: 0.0, epsilon: 0.06
# episode: 16750, score: 100.0, epsilon: 0.06
# episode: 16755, score: 0.0, epsilon: 0.06
# episode: 16760, score: 250.0, epsilon: 0.06
# episode: 16765, score: 0.0, epsilon: 0.06
# episode: 16770, score: 350.0, epsilon: 0.06
# episode: 16775, score: 100.0, epsilon: 0.06
# episode: 16780, score: 0.0, epsilon: 0.06
# episode: 16785, score: 250.0, epsilon: 0.06
# episode: 16790, score: 100.0, epsilon: 0.06
# episode: 16795, score: 0.0, epsilon: 0.06
# marking, episode: 16800, score: 200.0, mean_score: 143.00, std_score: 211.78
# episode: 16800, score: 200.0, epsilon: 0.06
# episode: 16805, score: 0.0, epsilon: 0.06
# episode: 16810, score: 700.0, epsilon: 0.06
# episode: 16815, score: 200.0, epsilon: 0.06
# episode: 16820, score: 500.0, epsilon: 0.06
# episode: 16825, score: 0.0, epsilon: 0.06
# episode: 16830, score: 0.0, epsilon: 0.06
# episode: 16835, score: 0.0, epsilon: 0.06
# episode: 16840, score: 250.0, epsilon: 0.06
# episode: 16845, score: 0.0, epsilon: 0.06
# episode: 16850, score: 500.0, epsilon: 0.06
# episode: 16855, score: 0.0, epsilon: 0.06
# episode: 16860, score: 750.0, epsilon: 0.06
# episode: 16865, score: 0.0, epsilon: 0.06
# episode: 16870, score: 800.0, epsilon: 0.06
# episode: 16875, score: 450.0, epsilon: 0.06
# episode: 16880, score: 0.0, epsilon: 0.06
# episode: 16885, score: 250.0, epsilon: 0.06
# episode: 16890, score: 0.0, epsilon: 0.06
# episode: 16895, score: 0.0, epsilon: 0.06
# marking, episode: 16900, score: 0.0, mean_score: 152.50, std_score: 204.13
# episode: 16900, score: 0.0, epsilon: 0.06
# episode: 16905, score: 0.0, epsilon: 0.06
# episode: 16910, score: 250.0, epsilon: 0.06
# episode: 16915, score: 0.0, epsilon: 0.06
# episode: 16920, score: 0.0, epsilon: 0.06
# episode: 16925, score: 0.0, epsilon: 0.06
# episode: 16930, score: 0.0, epsilon: 0.06
# episode: 16935, score: 0.0, epsilon: 0.06
# episode: 16940, score: 0.0, epsilon: 0.06
# episode: 16945, score: 0.0, epsilon: 0.06
# episode: 16950, score: 0.0, epsilon: 0.06
# episode: 16955, score: 0.0, epsilon: 0.06
# episode: 16960, score: 0.0, epsilon: 0.06
# episode: 16965, score: 0.0, epsilon: 0.06
# episode: 16970, score: 200.0, epsilon: 0.06
# episode: 16975, score: 0.0, epsilon: 0.06
# episode: 16980, score: 0.0, epsilon: 0.06
# episode: 16985, score: 350.0, epsilon: 0.06
# episode: 16990, score: 200.0, epsilon: 0.06
# episode: 16995, score: 0.0, epsilon: 0.06
# marking, episode: 17000, score: 800.0, mean_score: 133.00, std_score: 211.69
# episode: 17000, score: 800.0, epsilon: 0.06
# episode: 17005, score: 0.0, epsilon: 0.06
# episode: 17010, score: 100.0, epsilon: 0.06
# episode: 17015, score: 350.0, epsilon: 0.06
# episode: 17020, score: 850.0, epsilon: 0.06
# episode: 17025, score: 500.0, epsilon: 0.06
# episode: 17030, score: 250.0, epsilon: 0.06
# episode: 17035, score: 0.0, epsilon: 0.06
# episode: 17040, score: 100.0, epsilon: 0.06
# episode: 17045, score: 100.0, epsilon: 0.06
# episode: 17050, score: 0.0, epsilon: 0.06
# episode: 17055, score: 0.0, epsilon: 0.06
# episode: 17060, score: 500.0, epsilon: 0.06
# episode: 17065, score: 0.0, epsilon: 0.06
# episode: 17070, score: 0.0, epsilon: 0.06
# episode: 17075, score: 100.0, epsilon: 0.06
# episode: 17080, score: 600.0, epsilon: 0.06
# episode: 17085, score: 0.0, epsilon: 0.06
# episode: 17090, score: 100.0, epsilon: 0.06
# episode: 17095, score: 0.0, epsilon: 0.06
# marking, episode: 17100, score: 0.0, mean_score: 159.00, std_score: 217.87
# episode: 17100, score: 0.0, epsilon: 0.06
# episode: 17105, score: 350.0, epsilon: 0.06
# episode: 17110, score: 0.0, epsilon: 0.06
# episode: 17115, score: 0.0, epsilon: 0.06
# episode: 17120, score: 0.0, epsilon: 0.06
# episode: 17125, score: 100.0, epsilon: 0.06
# episode: 17130, score: 0.0, epsilon: 0.06
# episode: 17135, score: 0.0, epsilon: 0.06
# episode: 17140, score: 0.0, epsilon: 0.06
# episode: 17145, score: 0.0, epsilon: 0.06
# episode: 17150, score: 250.0, epsilon: 0.06
# episode: 17155, score: 0.0, epsilon: 0.06
# episode: 17160, score: 0.0, epsilon: 0.06
# episode: 17165, score: 0.0, epsilon: 0.06
# episode: 17170, score: 350.0, epsilon: 0.06
# episode: 17175, score: 0.0, epsilon: 0.06
# episode: 17180, score: 0.0, epsilon: 0.06
# episode: 17185, score: 500.0, epsilon: 0.06
# episode: 17190, score: 250.0, epsilon: 0.06
# episode: 17195, score: 0.0, epsilon: 0.06
# marking, episode: 17200, score: 0.0, mean_score: 129.00, std_score: 206.42
# episode: 17200, score: 0.0, epsilon: 0.06
# episode: 17205, score: 0.0, epsilon: 0.06
# episode: 17210, score: 0.0, epsilon: 0.06
# episode: 17215, score: 0.0, epsilon: 0.06
# episode: 17220, score: 100.0, epsilon: 0.06
# episode: 17225, score: 0.0, epsilon: 0.06
# episode: 17230, score: 500.0, epsilon: 0.06
# episode: 17235, score: 0.0, epsilon: 0.06
# episode: 17240, score: 0.0, epsilon: 0.06
# episode: 17245, score: 0.0, epsilon: 0.06
# episode: 17250, score: 0.0, epsilon: 0.06
# episode: 17255, score: 0.0, epsilon: 0.06
# episode: 17260, score: 0.0, epsilon: 0.06
# episode: 17265, score: 0.0, epsilon: 0.06
# episode: 17270, score: 600.0, epsilon: 0.06
# episode: 17275, score: 0.0, epsilon: 0.06
# episode: 17280, score: 350.0, epsilon: 0.06
# episode: 17285, score: 100.0, epsilon: 0.06
# episode: 17290, score: 0.0, epsilon: 0.06
# episode: 17295, score: 0.0, epsilon: 0.06
# marking, episode: 17300, score: 0.0, mean_score: 114.50, std_score: 195.49
# episode: 17300, score: 0.0, epsilon: 0.06
# episode: 17305, score: 0.0, epsilon: 0.06
# episode: 17310, score: 0.0, epsilon: 0.06
# episode: 17315, score: 0.0, epsilon: 0.06
# episode: 17320, score: 0.0, epsilon: 0.06
# episode: 17325, score: 0.0, epsilon: 0.06
# episode: 17330, score: 500.0, epsilon: 0.06
# episode: 17335, score: 100.0, epsilon: 0.06
# episode: 17340, score: 250.0, epsilon: 0.06
# episode: 17345, score: 500.0, epsilon: 0.06
# episode: 17350, score: 0.0, epsilon: 0.06
# episode: 17355, score: 0.0, epsilon: 0.06
# episode: 17360, score: 0.0, epsilon: 0.06
# episode: 17365, score: 100.0, epsilon: 0.06
# episode: 17370, score: 0.0, epsilon: 0.06
# episode: 17375, score: 100.0, epsilon: 0.06
# episode: 17380, score: 0.0, epsilon: 0.06
# episode: 17385, score: 350.0, epsilon: 0.06
# episode: 17390, score: 100.0, epsilon: 0.06
# episode: 17395, score: 0.0, epsilon: 0.06
# marking, episode: 17400, score: 100.0, mean_score: 111.00, std_score: 181.74
# episode: 17400, score: 100.0, epsilon: 0.06
# episode: 17405, score: 0.0, epsilon: 0.06
# episode: 17410, score: 0.0, epsilon: 0.06
# episode: 17415, score: 0.0, epsilon: 0.06
# episode: 17420, score: 100.0, epsilon: 0.06
# episode: 17425, score: 0.0, epsilon: 0.06
# episode: 17430, score: 0.0, epsilon: 0.06
# episode: 17435, score: 0.0, epsilon: 0.06
# episode: 17440, score: 100.0, epsilon: 0.06
# episode: 17445, score: 0.0, epsilon: 0.06
# episode: 17450, score: 600.0, epsilon: 0.06
# episode: 17455, score: 0.0, epsilon: 0.06
# episode: 17460, score: 0.0, epsilon: 0.06
# episode: 17465, score: 0.0, epsilon: 0.06
# episode: 17470, score: 0.0, epsilon: 0.06
# episode: 17475, score: 100.0, epsilon: 0.06
# episode: 17480, score: 0.0, epsilon: 0.06
# episode: 17485, score: 100.0, epsilon: 0.06
# episode: 17490, score: 0.0, epsilon: 0.06
# episode: 17495, score: 350.0, epsilon: 0.06
# marking, episode: 17500, score: 100.0, mean_score: 159.50, std_score: 230.40
# episode: 17500, score: 100.0, epsilon: 0.06
# episode: 17505, score: 100.0, epsilon: 0.06
# episode: 17510, score: 200.0, epsilon: 0.06
# episode: 17515, score: 0.0, epsilon: 0.06
# episode: 17520, score: 0.0, epsilon: 0.06
# episode: 17525, score: 0.0, epsilon: 0.06
# episode: 17530, score: 250.0, epsilon: 0.06
# episode: 17535, score: 0.0, epsilon: 0.06
# episode: 17540, score: 350.0, epsilon: 0.06
# episode: 17545, score: 0.0, epsilon: 0.06
# episode: 17550, score: 350.0, epsilon: 0.06
# episode: 17555, score: 0.0, epsilon: 0.06
# episode: 17560, score: 0.0, epsilon: 0.06
# episode: 17565, score: 0.0, epsilon: 0.06
# episode: 17570, score: 250.0, epsilon: 0.06
# episode: 17575, score: 0.0, epsilon: 0.06
# episode: 17580, score: 450.0, epsilon: 0.06
# episode: 17585, score: 0.0, epsilon: 0.06
# episode: 17590, score: 500.0, epsilon: 0.06
# episode: 17595, score: 0.0, epsilon: 0.06
# marking, episode: 17600, score: 0.0, mean_score: 132.50, std_score: 218.33
# episode: 17600, score: 0.0, epsilon: 0.06
# episode: 17605, score: 0.0, epsilon: 0.06
# episode: 17610, score: 0.0, epsilon: 0.06
# episode: 17615, score: 0.0, epsilon: 0.06
# episode: 17620, score: 0.0, epsilon: 0.06
# episode: 17625, score: 250.0, epsilon: 0.06
# episode: 17630, score: 0.0, epsilon: 0.06
# episode: 17635, score: 0.0, epsilon: 0.06
# episode: 17640, score: 350.0, epsilon: 0.06
# episode: 17645, score: 0.0, epsilon: 0.06
# episode: 17650, score: 0.0, epsilon: 0.06
# episode: 17655, score: 0.0, epsilon: 0.06
# episode: 17660, score: 350.0, epsilon: 0.06
# episode: 17665, score: 500.0, epsilon: 0.06
# episode: 17670, score: 0.0, epsilon: 0.06
# episode: 17675, score: 0.0, epsilon: 0.06
# episode: 17680, score: 0.0, epsilon: 0.06
# episode: 17685, score: 250.0, epsilon: 0.06
# episode: 17690, score: 500.0, epsilon: 0.06
# episode: 17695, score: 0.0, epsilon: 0.06
# marking, episode: 17700, score: 250.0, mean_score: 147.50, std_score: 195.11
# episode: 17700, score: 250.0, epsilon: 0.06
# episode: 17705, score: 500.0, epsilon: 0.06
# episode: 17710, score: 0.0, epsilon: 0.06
# episode: 17715, score: 100.0, epsilon: 0.06
# episode: 17720, score: 450.0, epsilon: 0.06
# episode: 17725, score: 0.0, epsilon: 0.06
# episode: 17730, score: 0.0, epsilon: 0.06
# episode: 17735, score: 500.0, epsilon: 0.06
# episode: 17740, score: 0.0, epsilon: 0.06
# episode: 17745, score: 0.0, epsilon: 0.06
# episode: 17750, score: 100.0, epsilon: 0.06
# episode: 17755, score: 100.0, epsilon: 0.06
# episode: 17760, score: 0.0, epsilon: 0.06
# episode: 17765, score: 0.0, epsilon: 0.06
# episode: 17770, score: 0.0, epsilon: 0.06
# episode: 17775, score: 0.0, epsilon: 0.06
# episode: 17780, score: 0.0, epsilon: 0.06
# episode: 17785, score: 100.0, epsilon: 0.06
# episode: 17790, score: 100.0, epsilon: 0.06
# episode: 17795, score: 250.0, epsilon: 0.06
# marking, episode: 17800, score: 500.0, mean_score: 135.50, std_score: 204.73
# episode: 17800, score: 500.0, epsilon: 0.06
# episode: 17805, score: 350.0, epsilon: 0.06
# episode: 17810, score: 350.0, epsilon: 0.06
# episode: 17815, score: 250.0, epsilon: 0.06
# episode: 17820, score: 0.0, epsilon: 0.06
# episode: 17825, score: 0.0, epsilon: 0.06
# episode: 17830, score: 0.0, epsilon: 0.06
# episode: 17835, score: 350.0, epsilon: 0.06
# episode: 17840, score: 250.0, epsilon: 0.06
# episode: 17845, score: 0.0, epsilon: 0.06
# episode: 17850, score: 500.0, epsilon: 0.06
# episode: 17855, score: 0.0, epsilon: 0.06
# episode: 17860, score: 100.0, epsilon: 0.06
# episode: 17865, score: 100.0, epsilon: 0.06
# episode: 17870, score: 200.0, epsilon: 0.06
# episode: 17875, score: 0.0, epsilon: 0.06
# episode: 17880, score: 0.0, epsilon: 0.06
# episode: 17885, score: 600.0, epsilon: 0.06
# episode: 17890, score: 250.0, epsilon: 0.06
# episode: 17895, score: 0.0, epsilon: 0.06
# marking, episode: 17900, score: 500.0, mean_score: 166.50, std_score: 218.98
# episode: 17900, score: 500.0, epsilon: 0.06
# episode: 17905, score: 0.0, epsilon: 0.06
# episode: 17910, score: 500.0, epsilon: 0.06
# episode: 17915, score: 850.0, epsilon: 0.06
# episode: 17920, score: 100.0, epsilon: 0.06
# episode: 17925, score: 100.0, epsilon: 0.06
# episode: 17930, score: 100.0, epsilon: 0.06
# episode: 17935, score: 0.0, epsilon: 0.06
# episode: 17940, score: 0.0, epsilon: 0.06
# episode: 17945, score: 250.0, epsilon: 0.06
# episode: 17950, score: 0.0, epsilon: 0.06
# episode: 17955, score: 0.0, epsilon: 0.06
# episode: 17960, score: 0.0, epsilon: 0.06
# episode: 17965, score: 0.0, epsilon: 0.06
# episode: 17970, score: 250.0, epsilon: 0.06
# episode: 17975, score: 0.0, epsilon: 0.06
# episode: 17980, score: 500.0, epsilon: 0.06
# episode: 17985, score: 0.0, epsilon: 0.06
# episode: 17990, score: 500.0, epsilon: 0.06
# episode: 17995, score: 0.0, epsilon: 0.06
# marking, episode: 18000, score: 850.0, mean_score: 148.50, std_score: 231.46
# episode: 18000, score: 850.0, epsilon: 0.06
# episode: 18005, score: 100.0, epsilon: 0.06
# episode: 18010, score: 0.0, epsilon: 0.06
# episode: 18015, score: 0.0, epsilon: 0.06
# episode: 18020, score: 0.0, epsilon: 0.06
# episode: 18025, score: 350.0, epsilon: 0.06
# episode: 18030, score: 250.0, epsilon: 0.06
# episode: 18035, score: 0.0, epsilon: 0.06
# episode: 18040, score: 0.0, epsilon: 0.06
# episode: 18045, score: 0.0, epsilon: 0.06
# episode: 18050, score: 450.0, epsilon: 0.06
# episode: 18055, score: 0.0, epsilon: 0.06
# episode: 18060, score: 100.0, epsilon: 0.06
# episode: 18065, score: 0.0, epsilon: 0.06
# episode: 18070, score: 0.0, epsilon: 0.06
# episode: 18075, score: 350.0, epsilon: 0.06
# episode: 18080, score: 350.0, epsilon: 0.06
# episode: 18085, score: 100.0, epsilon: 0.06
# episode: 18090, score: 0.0, epsilon: 0.06
# episode: 18095, score: 0.0, epsilon: 0.06
# marking, episode: 18100, score: 850.0, mean_score: 117.00, std_score: 196.24
# episode: 18100, score: 850.0, epsilon: 0.06
# episode: 18105, score: 600.0, epsilon: 0.06
# episode: 18110, score: 100.0, epsilon: 0.06
# episode: 18115, score: 500.0, epsilon: 0.06
# episode: 18120, score: 0.0, epsilon: 0.06
# episode: 18125, score: 0.0, epsilon: 0.06
# episode: 18130, score: 0.0, epsilon: 0.06
# episode: 18135, score: 0.0, epsilon: 0.06
# episode: 18140, score: 0.0, epsilon: 0.06
# episode: 18145, score: 500.0, epsilon: 0.06
# episode: 18150, score: 250.0, epsilon: 0.06
# episode: 18155, score: 350.0, epsilon: 0.06
# episode: 18160, score: 100.0, epsilon: 0.06
# episode: 18165, score: 0.0, epsilon: 0.06
# episode: 18170, score: 0.0, epsilon: 0.06
# episode: 18175, score: 0.0, epsilon: 0.06
# episode: 18180, score: 100.0, epsilon: 0.06
# episode: 18185, score: 600.0, epsilon: 0.06
