# %%
# optional Google drive integration - this will allow you to save and resume training, and may speed up redownloading the dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **DQN**

# %%
# this is a Deep Q Learning (DQN) agent including replay memory and a target network 
# you can write a brief 8-10 line abstract detailing your submission and experiments here
# the code is based on https://github.com/seungeunrho/minimalRL/blob/master/dqn.py, which is released under the MIT licesne
# make sure you reference any code you have studied as above, with one comment line per reference

# imports
import gym
import collections
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# hyperparameters
learning_rate = 0.0005
gamma = 0.98
buffer_limit = 50000
batch_size = 32
video_every = 50
print_every = 5

class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)
    
    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])

        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
               torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
               torch.tensor(done_mask_lst)
    
    def size(self):
        return len(self.buffer)

class QNetwork(nn.Module):
    def __init__(self):
        super(QNetwork, self).__init__()
        # input expands to a flat vector
        self.fc1 = nn.Linear(np.array(env.observation_space.shape).prod(), 256)
        self.fc2 = nn.Linear(256, 84)
        self.fc3 = nn.Linear(84, env.action_space.n)

    def forward(self, x):
        x = x.view(x.size(0),-1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
      
    def sample_action(self, obs, epsilon):
        out = self.forward(obs)
        coin = random.random()
        if coin < epsilon:
            return random.randint(0,17)
        else : 
            return out.argmax().item()
            
def train(q, q_target, memory, optimizer):
    for i in range(10):
        s,a,r,s_prime,done_mask = memory.sample(batch_size)

        q_out = q(s)
        q_a = q_out.gather(1,a)  # gather: select value according to the index
        # print(q_a.shape)
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
        # print(max_q_prime.shape)
        target = r + gamma * max_q_prime * done_mask
        loss = F.smooth_l1_loss(q_a, target)
        # print(loss)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %% [markdown]
# **DQN Train**

# %%
# setup the Gravitar ram environment, and record a video every 50 episodes. You can use the non-ram version here if you prefer
env = gym.make('Gravitar-ram-v0')
env = gym.wrappers.Monitor(env, "drive/My Drive/rl/video", video_callable=lambda episode_id: (episode_id%video_every)==0,force=True)

# reproducible environment and action spaces, do not change lines 6-11 here (tools > settings > editor > show line numbers)
seed = 742
torch.manual_seed(seed)
env.seed(seed)
random.seed(seed)
np.random.seed(seed)
env.action_space.seed(seed)

q = QNetwork()
q_target = QNetwork()
q_target.load_state_dict(q.state_dict())
memory = ReplayBuffer()

score    = 0.0
marking  = []
optimizer = optim.Adam(q.parameters(), lr=learning_rate)

for n_episode in range(int(1e32)):
    epsilon = max(0.01, 0.08 - 0.01*(n_episode/200)) # linear annealing from 8% to 1%
    s = env.reset()
    # print(len(s))
    done = False
    score = 0.0

    while True:
        # print(torch.from_numpy(s).float().shape)
        a = q.sample_action(torch.from_numpy(s).float().unsqueeze(0), epsilon)
        # print(a)
        s_prime, r, done, info = env.step(a)
        done_mask = 0.0 if done else 1.0
        memory.put((s,a,r/100.0,s_prime, done_mask))
        s = s_prime

        score += r
        if done:
            break
        
    if memory.size()>2000:
        train(q, q_target, memory, optimizer)
        # q.update_critic(memory)
        # q.update_policy(memory)

    # do not change lines 44-48 here, they are for marking the submission log
    marking.append(score)
    if n_episode%100 == 0:
        print("marking, episode: {}, score: {:.1f}, mean_score: {:.2f}, std_score: {:.2f}".format(
            n_episode, score, np.array(marking).mean(), np.array(marking).std()))
        marking = []

    # you can change this part, and print any data you like (so long as it doesn't start with "marking")
    if n_episode%print_every==0 and n_episode!=0:
        q_target.load_state_dict(q.state_dict())
        # hard_update(q.target_policy, q.policy)
        # hard_update(q.target_critic, q.critic)
        print("episode: {}, score: {:.1f}, epsilon: {:.2f}".format(n_episode, score, epsilon))
# Out:
# marking, episode: 0, score: 250.0, mean_score: 250.00, std_score: 0.00
# episode: 5, score: 0.0, epsilon: 0.08
# episode: 10, score: 100.0, epsilon: 0.08
# episode: 15, score: 0.0, epsilon: 0.08
# episode: 20, score: 0.0, epsilon: 0.08
# episode: 25, score: 250.0, epsilon: 0.08
# episode: 30, score: 100.0, epsilon: 0.08
# episode: 35, score: 200.0, epsilon: 0.08
# episode: 40, score: 0.0, epsilon: 0.08
# episode: 45, score: 100.0, epsilon: 0.08
# episode: 50, score: 0.0, epsilon: 0.08
# episode: 55, score: 0.0, epsilon: 0.08
# episode: 60, score: 250.0, epsilon: 0.08
# episode: 65, score: 700.0, epsilon: 0.08
# episode: 70, score: 350.0, epsilon: 0.08
# episode: 75, score: 0.0, epsilon: 0.08
# episode: 80, score: 0.0, epsilon: 0.08
# episode: 85, score: 250.0, epsilon: 0.08
# episode: 90, score: 500.0, epsilon: 0.08
# episode: 95, score: 0.0, epsilon: 0.08
# marking, episode: 100, score: 0.0, mean_score: 125.50, std_score: 188.35
# episode: 100, score: 0.0, epsilon: 0.07
# episode: 105, score: 250.0, epsilon: 0.07
# episode: 110, score: 0.0, epsilon: 0.07
# episode: 115, score: 0.0, epsilon: 0.07
# episode: 120, score: 0.0, epsilon: 0.07
# episode: 125, score: 100.0, epsilon: 0.07
# episode: 130, score: 0.0, epsilon: 0.07
# episode: 135, score: 0.0, epsilon: 0.07
# episode: 140, score: 250.0, epsilon: 0.07
# episode: 145, score: 0.0, epsilon: 0.07
# episode: 150, score: 100.0, epsilon: 0.07
# episode: 155, score: 100.0, epsilon: 0.07
# episode: 160, score: 0.0, epsilon: 0.07
# episode: 165, score: 0.0, epsilon: 0.07
# episode: 170, score: 500.0, epsilon: 0.07
# episode: 175, score: 0.0, epsilon: 0.07
# episode: 180, score: 0.0, epsilon: 0.07
# episode: 185, score: 100.0, epsilon: 0.07
# episode: 190, score: 100.0, epsilon: 0.07
# episode: 195, score: 0.0, epsilon: 0.07
# marking, episode: 200, score: 100.0, mean_score: 112.50, std_score: 172.25
# episode: 200, score: 100.0, epsilon: 0.07
# episode: 205, score: 100.0, epsilon: 0.07
# episode: 210, score: 0.0, epsilon: 0.07
# episode: 215, score: 0.0, epsilon: 0.07
# episode: 220, score: 0.0, epsilon: 0.07
# episode: 225, score: 250.0, epsilon: 0.07
# episode: 230, score: 450.0, epsilon: 0.07
# episode: 235, score: 350.0, epsilon: 0.07
# episode: 240, score: 100.0, epsilon: 0.07
# episode: 245, score: 0.0, epsilon: 0.07
# episode: 250, score: 100.0, epsilon: 0.07
# episode: 255, score: 0.0, epsilon: 0.07
# episode: 260, score: 700.0, epsilon: 0.07
# episode: 265, score: 0.0, epsilon: 0.07
# episode: 270, score: 0.0, epsilon: 0.07
# episode: 275, score: 350.0, epsilon: 0.07
# episode: 280, score: 200.0, epsilon: 0.07
# episode: 285, score: 0.0, epsilon: 0.07
# episode: 290, score: 500.0, epsilon: 0.07
# episode: 295, score: 0.0, epsilon: 0.07
# marking, episode: 300, score: 0.0, mean_score: 93.50, std_score: 159.16
# episode: 300, score: 0.0, epsilon: 0.07
# episode: 305, score: 250.0, epsilon: 0.06
# episode: 310, score: 0.0, epsilon: 0.06
# episode: 315, score: 0.0, epsilon: 0.06
# episode: 320, score: 250.0, epsilon: 0.06
# episode: 325, score: 0.0, epsilon: 0.06
# episode: 330, score: 0.0, epsilon: 0.06
# episode: 335, score: 700.0, epsilon: 0.06
# episode: 340, score: 0.0, epsilon: 0.06
# episode: 345, score: 100.0, epsilon: 0.06
# episode: 350, score: 0.0, epsilon: 0.06
# episode: 355, score: 0.0, epsilon: 0.06
# episode: 360, score: 0.0, epsilon: 0.06
# episode: 365, score: 0.0, epsilon: 0.06
# episode: 370, score: 0.0, epsilon: 0.06
# episode: 375, score: 0.0, epsilon: 0.06
# episode: 380, score: 0.0, epsilon: 0.06
# episode: 385, score: 0.0, epsilon: 0.06
# episode: 390, score: 0.0, epsilon: 0.06
# episode: 395, score: 0.0, epsilon: 0.06
# marking, episode: 400, score: 0.0, mean_score: 94.50, std_score: 169.54
# episode: 400, score: 0.0, epsilon: 0.06
# episode: 405, score: 0.0, epsilon: 0.06
# episode: 410, score: 0.0, epsilon: 0.06
# episode: 415, score: 0.0, epsilon: 0.06
# episode: 420, score: 0.0, epsilon: 0.06
# episode: 425, score: 0.0, epsilon: 0.06
# episode: 430, score: 0.0, epsilon: 0.06
# episode: 435, score: 0.0, epsilon: 0.06
# episode: 440, score: 100.0, epsilon: 0.06
# episode: 445, score: 0.0, epsilon: 0.06
# episode: 450, score: 100.0, epsilon: 0.06
# episode: 455, score: 0.0, epsilon: 0.06
# episode: 460, score: 100.0, epsilon: 0.06
# episode: 465, score: 0.0, epsilon: 0.06
# episode: 470, score: 0.0, epsilon: 0.06
# episode: 475, score: 0.0, epsilon: 0.06
# episode: 480, score: 600.0, epsilon: 0.06
# episode: 485, score: 100.0, epsilon: 0.06
# episode: 490, score: 0.0, epsilon: 0.06
# episode: 495, score: 0.0, epsilon: 0.06
# marking, episode: 500, score: 0.0, mean_score: 66.00, std_score: 127.84
# episode: 500, score: 0.0, epsilon: 0.06
# episode: 505, score: 450.0, epsilon: 0.05
# episode: 510, score: 0.0, epsilon: 0.05
# episode: 515, score: 0.0, epsilon: 0.05
# episode: 520, score: 250.0, epsilon: 0.05
# episode: 525, score: 200.0, epsilon: 0.05
# episode: 530, score: 0.0, epsilon: 0.05
# episode: 535, score: 0.0, epsilon: 0.05
# episode: 540, score: 500.0, epsilon: 0.05
# episode: 545, score: 0.0, epsilon: 0.05
# episode: 550, score: 350.0, epsilon: 0.05
# episode: 555, score: 250.0, epsilon: 0.05
# episode: 560, score: 0.0, epsilon: 0.05
# episode: 565, score: 100.0, epsilon: 0.05
# episode: 570, score: 0.0, epsilon: 0.05
# episode: 575, score: 0.0, epsilon: 0.05
# episode: 580, score: 0.0, epsilon: 0.05
# episode: 585, score: 100.0, epsilon: 0.05
# episode: 590, score: 0.0, epsilon: 0.05
# episode: 595, score: 350.0, epsilon: 0.05
# marking, episode: 600, score: 100.0, mean_score: 97.00, std_score: 160.75
# episode: 600, score: 100.0, epsilon: 0.05
# episode: 605, score: 0.0, epsilon: 0.05
# episode: 610, score: 0.0, epsilon: 0.05
# episode: 615, score: 0.0, epsilon: 0.05
# episode: 620, score: 350.0, epsilon: 0.05
# episode: 625, score: 0.0, epsilon: 0.05
# episode: 630, score: 100.0, epsilon: 0.05
# episode: 635, score: 0.0, epsilon: 0.05
# episode: 640, score: 100.0, epsilon: 0.05
# episode: 645, score: 0.0, epsilon: 0.05
# episode: 650, score: 0.0, epsilon: 0.05
# episode: 655, score: 0.0, epsilon: 0.05
# episode: 660, score: 450.0, epsilon: 0.05
# episode: 665, score: 300.0, epsilon: 0.05
# episode: 670, score: 250.0, epsilon: 0.05
# episode: 675, score: 0.0, epsilon: 0.05
# episode: 680, score: 100.0, epsilon: 0.05
# episode: 685, score: 0.0, epsilon: 0.05
# episode: 690, score: 0.0, epsilon: 0.05
# episode: 695, score: 0.0, epsilon: 0.05
# marking, episode: 700, score: 0.0, mean_score: 55.00, std_score: 110.79
# episode: 700, score: 0.0, epsilon: 0.04
# episode: 705, score: 0.0, epsilon: 0.04
# episode: 710, score: 0.0, epsilon: 0.04
# episode: 715, score: 100.0, epsilon: 0.04
# episode: 720, score: 100.0, epsilon: 0.04
# episode: 725, score: 0.0, epsilon: 0.04
# episode: 730, score: 200.0, epsilon: 0.04
# episode: 735, score: 0.0, epsilon: 0.04
# episode: 740, score: 0.0, epsilon: 0.04
# episode: 745, score: 0.0, epsilon: 0.04
# episode: 750, score: 0.0, epsilon: 0.04
# episode: 755, score: 0.0, epsilon: 0.04
# episode: 760, score: 0.0, epsilon: 0.04
# episode: 765, score: 0.0, epsilon: 0.04
# episode: 770, score: 0.0, epsilon: 0.04
# episode: 775, score: 0.0, epsilon: 0.04
# episode: 780, score: 0.0, epsilon: 0.04
# episode: 785, score: 100.0, epsilon: 0.04
# episode: 790, score: 0.0, epsilon: 0.04
# episode: 795, score: 0.0, epsilon: 0.04
# marking, episode: 800, score: 0.0, mean_score: 51.00, std_score: 129.80
# episode: 800, score: 0.0, epsilon: 0.04
# episode: 805, score: 0.0, epsilon: 0.04
# episode: 810, score: 0.0, epsilon: 0.04
# episode: 815, score: 250.0, epsilon: 0.04
# episode: 820, score: 0.0, epsilon: 0.04
# episode: 825, score: 200.0, epsilon: 0.04
# episode: 830, score: 0.0, epsilon: 0.04
# episode: 835, score: 0.0, epsilon: 0.04
# episode: 840, score: 450.0, epsilon: 0.04
# episode: 845, score: 0.0, epsilon: 0.04
# episode: 850, score: 0.0, epsilon: 0.04
# episode: 855, score: 0.0, epsilon: 0.04
# episode: 860, score: 0.0, epsilon: 0.04
# episode: 865, score: 0.0, epsilon: 0.04
# episode: 870, score: 0.0, epsilon: 0.04
# episode: 875, score: 0.0, epsilon: 0.04
# episode: 880, score: 0.0, epsilon: 0.04
# episode: 885, score: 0.0, epsilon: 0.04
# episode: 890, score: 0.0, epsilon: 0.04
# episode: 895, score: 100.0, epsilon: 0.04
# marking, episode: 900, score: 0.0, mean_score: 38.00, std_score: 99.03
# episode: 900, score: 0.0, epsilon: 0.04
# episode: 905, score: 0.0, epsilon: 0.03
# episode: 910, score: 0.0, epsilon: 0.03
# episode: 915, score: 100.0, epsilon: 0.03
# episode: 920, score: 0.0, epsilon: 0.03
# episode: 925, score: 0.0, epsilon: 0.03
# episode: 930, score: 0.0, epsilon: 0.03
# episode: 935, score: 250.0, epsilon: 0.03
# episode: 940, score: 0.0, epsilon: 0.03
# episode: 945, score: 0.0, epsilon: 0.03
# episode: 950, score: 0.0, epsilon: 0.03
# episode: 955, score: 0.0, epsilon: 0.03
# episode: 960, score: 250.0, epsilon: 0.03
# episode: 965, score: 250.0, epsilon: 0.03
# episode: 970, score: 100.0, epsilon: 0.03
# episode: 975, score: 0.0, epsilon: 0.03
# episode: 980, score: 250.0, epsilon: 0.03
# episode: 985, score: 350.0, epsilon: 0.03
# episode: 990, score: 0.0, epsilon: 0.03
# episode: 995, score: 0.0, epsilon: 0.03
# marking, episode: 1000, score: 0.0, mean_score: 80.00, std_score: 149.50
# episode: 1000, score: 0.0, epsilon: 0.03
# episode: 1005, score: 200.0, epsilon: 0.03
# episode: 1010, score: 0.0, epsilon: 0.03
# episode: 1015, score: 0.0, epsilon: 0.03
# episode: 1020, score: 0.0, epsilon: 0.03
# episode: 1025, score: 0.0, epsilon: 0.03
# episode: 1030, score: 200.0, epsilon: 0.03
# episode: 1035, score: 0.0, epsilon: 0.03
# episode: 1040, score: 0.0, epsilon: 0.03
# episode: 1045, score: 0.0, epsilon: 0.03
# episode: 1050, score: 0.0, epsilon: 0.03
# episode: 1055, score: 0.0, epsilon: 0.03
# episode: 1060, score: 0.0, epsilon: 0.03
# episode: 1065, score: 250.0, epsilon: 0.03
# episode: 1070, score: 0.0, epsilon: 0.03
# episode: 1075, score: 0.0, epsilon: 0.03
# episode: 1080, score: 700.0, epsilon: 0.03
# episode: 1085, score: 0.0, epsilon: 0.03
# episode: 1090, score: 0.0, epsilon: 0.03
# episode: 1095, score: 450.0, epsilon: 0.03
# marking, episode: 1100, score: 0.0, mean_score: 73.00, std_score: 156.43
# episode: 1100, score: 0.0, epsilon: 0.03
# episode: 1105, score: 0.0, epsilon: 0.02
# episode: 1110, score: 250.0, epsilon: 0.02
# episode: 1115, score: 0.0, epsilon: 0.02
# episode: 1120, score: 0.0, epsilon: 0.02
# episode: 1125, score: 0.0, epsilon: 0.02
# episode: 1130, score: 500.0, epsilon: 0.02
# episode: 1135, score: 500.0, epsilon: 0.02
# episode: 1140, score: 0.0, epsilon: 0.02
# episode: 1145, score: 0.0, epsilon: 0.02
# episode: 1150, score: 0.0, epsilon: 0.02
# episode: 1155, score: 0.0, epsilon: 0.02
# episode: 1160, score: 0.0, epsilon: 0.02
# episode: 1165, score: 0.0, epsilon: 0.02
# episode: 1170, score: 0.0, epsilon: 0.02
# episode: 1175, score: 0.0, epsilon: 0.02
# episode: 1180, score: 500.0, epsilon: 0.02
# episode: 1185, score: 100.0, epsilon: 0.02
# episode: 1190, score: 600.0, epsilon: 0.02
# episode: 1195, score: 0.0, epsilon: 0.02
# marking, episode: 1200, score: 500.0, mean_score: 119.50, std_score: 190.25
# episode: 1200, score: 500.0, epsilon: 0.02
# episode: 1205, score: 0.0, epsilon: 0.02
# episode: 1210, score: 350.0, epsilon: 0.02
# episode: 1215, score: 0.0, epsilon: 0.02
# episode: 1220, score: 0.0, epsilon: 0.02
# episode: 1225, score: 100.0, epsilon: 0.02
# episode: 1230, score: 0.0, epsilon: 0.02
# episode: 1235, score: 0.0, epsilon: 0.02
# episode: 1240, score: 0.0, epsilon: 0.02
# episode: 1245, score: 0.0, epsilon: 0.02
# episode: 1250, score: 0.0, epsilon: 0.02
# episode: 1255, score: 250.0, epsilon: 0.02
# episode: 1260, score: 0.0, epsilon: 0.02
# episode: 1265, score: 0.0, epsilon: 0.02
# episode: 1270, score: 0.0, epsilon: 0.02
# episode: 1275, score: 0.0, epsilon: 0.02
# episode: 1280, score: 0.0, epsilon: 0.02
# episode: 1285, score: 600.0, epsilon: 0.02
# episode: 1290, score: 0.0, epsilon: 0.02
# episode: 1295, score: 100.0, epsilon: 0.02
# marking, episode: 1300, score: 500.0, mean_score: 54.50, std_score: 134.55
# episode: 1300, score: 500.0, epsilon: 0.01
# episode: 1305, score: 0.0, epsilon: 0.01
# episode: 1310, score: 500.0, epsilon: 0.01
# episode: 1315, score: 250.0, epsilon: 0.01
# episode: 1320, score: 0.0, epsilon: 0.01
# episode: 1325, score: 250.0, epsilon: 0.01
# episode: 1330, score: 0.0, epsilon: 0.01
# episode: 1335, score: 350.0, epsilon: 0.01
# episode: 1340, score: 0.0, epsilon: 0.01
# episode: 1345, score: 0.0, epsilon: 0.01
# episode: 1350, score: 100.0, epsilon: 0.01
# episode: 1355, score: 0.0, epsilon: 0.01
# episode: 1360, score: 0.0, epsilon: 0.01
# episode: 1365, score: 0.0, epsilon: 0.01
# episode: 1370, score: 350.0, epsilon: 0.01
# episode: 1375, score: 0.0, epsilon: 0.01
# episode: 1380, score: 0.0, epsilon: 0.01
# episode: 1385, score: 350.0, epsilon: 0.01
# episode: 1390, score: 500.0, epsilon: 0.01
# episode: 1395, score: 0.0, epsilon: 0.01
# marking, episode: 1400, score: 0.0, mean_score: 83.00, std_score: 156.72
# episode: 1400, score: 0.0, epsilon: 0.01
# episode: 1405, score: 0.0, epsilon: 0.01
# episode: 1410, score: 250.0, epsilon: 0.01
# episode: 1415, score: 0.0, epsilon: 0.01
# episode: 1420, score: 350.0, epsilon: 0.01
# episode: 1425, score: 250.0, epsilon: 0.01
# episode: 1430, score: 0.0, epsilon: 0.01
# episode: 1435, score: 0.0, epsilon: 0.01
# episode: 1440, score: 0.0, epsilon: 0.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-5ef056e5f144> in <module>()
#      41
#      42     if memory.size()>2000:
# ---> 43         train(q, q_target, memory, optimizer)
#      44         # q.update_critic(memory)
#      45         # q.update_policy(memory)
#
# <ipython-input-48-c2dc6f54d000> in train(q, q_target, memory, optimizer)
#      71 def train(q, q_target, memory, optimizer):
#      72     for i in range(10):
# ---> 73         s,a,r,s_prime,done_mask = memory.sample(batch_size)
#      74
#      75         q_out = q(s)
#
# <ipython-input-48-c2dc6f54d000> in sample(self, n)
#      41             done_mask_lst.append([done_mask])
#      42
# ---> 43         return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst),                torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float),                torch.tensor(done_mask_lst)
#      44
#      45     def size(self):
#
# KeyboardInterrupt:

# %% [markdown]
# **SAC**

# %%
# this is a Deep Q Learning (DQN) agent including replay memory and a target network 
# you can write a brief 8-10 line abstract detailing your submission and experiments here
# the code is based on https://github.com/seungeunrho/minimalRL/blob/master/dqn.py, which is released under the MIT licesne
# make sure you reference any code you have studied as above, with one comment line per reference

# TODO: SAC baseline ?

# imports
import gym
import collections
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# hyperparameters
learning_rate = 0.0005
gamma = 0.9
buffer_limit = 50000
batch_size = 32
video_every = 50
print_every = 5

class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)
    
    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])

        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
               torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
               torch.tensor(done_mask_lst)
    
    def size(self):
        return len(self.buffer)


def hard_update(target, source):
    """
    Copy network parameters from source to target
    Inputs:
        target (torch.nn.Module): Net to copy parameters to
        source (torch.nn.Module): Net whose parameters to copy
    """
    for target_param, param in zip(target.parameters(), source.parameters()):
        target_param.data.copy_(param.data)

def disable_gradients(module):
    for p in module.parameters():
        p.requires_grad = False

def enable_gradients(module):
    for p in module.parameters():
        p.requires_grad = True

class SAC(nn.Module):
    def __init__(self):
        super(SAC, self).__init__()
        self.reward_scale = 100.0
        self.policy = nn.Sequential(
            nn.Linear(np.array(env.observation_space.shape).prod(), 256),
            nn.LeakyReLU(inplace=True),
            nn.Linear(256, 84),
            nn.LeakyReLU(inplace=True),
            nn.Linear(84, env.action_space.n)
        )

        self.target_policy = nn.Sequential(
            nn.Linear(np.array(env.observation_space.shape).prod(), 256),
            nn.LeakyReLU(inplace=True),
            nn.Linear(256, 84),
            nn.LeakyReLU(inplace=True),
            nn.Linear(84, env.action_space.n)
        )

        hard_update(self.target_policy, self.policy)
        input_size = int(np.array(env.observation_space.shape).prod()+np.array(env.action_space.shape).prod())
        self.critic = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.LeakyReLU(inplace=True),
            nn.Linear(256, 84),
            nn.LeakyReLU(inplace=True),
            nn.Linear(84, 1)
        )

        self.target_critic = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.LeakyReLU(inplace=True),
            nn.Linear(256, 84),
            nn.LeakyReLU(inplace=True),
            nn.Linear(84, 1)
        )
        hard_update(self.target_critic, self.critic)
        self.policy_optimizer = optim.Adam(self.policy.parameters(), lr=learning_rate)
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=learning_rate)

    def update_critic(self, memory, soft=True):
      for i in range(10):
        s,a,r,s_prime,done_mask = memory.sample(batch_size)
        # print(s.shape, a.shape)

        x = torch.from_numpy(np.concatenate((s,a), axis=1)).float()
        # print(x.shape)
        q_out = self.critic(x)
        # print(q_out.shape)
        # q_a = q_out.gather(1,a)  # gather: select value according to the index
        s_prime = s_prime.view(s_prime.size(0),-1)
        a_prime = self.target_policy(s_prime).argmax(1).unsqueeze(1)
        # print(a_prime.shape)
        out = self.target_policy(s_prime)
        log_pi = (F.log_softmax(out, dim=1)*F.softmax(out, dim=1)).sum(1).unsqueeze(1)
        # print(log_pi.shape)
        x_prime = torch.from_numpy(np.concatenate((s_prime,a_prime), axis=1)).float()
        # print(x_prime.shape)
        x_prime = x_prime.view(x_prime.size(0),-1)

        max_q_prime = self.target_critic(x_prime)
        target = r + gamma * max_q_prime * done_mask
        if soft:
          target -= log_pi / self.reward_scale

        loss_fn = nn.MSELoss()
        loss = 0.5*loss_fn(q_out, target)
        # print(loss)
        
        self.critic_optimizer.zero_grad()
        loss.backward()
        self.critic_optimizer.step()

    def update_policy(self, memory):
      for i in range(10):
        s,a,r,s_prime,done_mask = memory.sample(batch_size)
        x = torch.from_numpy(np.concatenate((s,a), axis=1)).float()

        q_out = self.critic(x)
        # s_prime = s_prime.view(s_prime.size(0),-1)
        # a_prime = self.target_policy(s_prime).argmax(1).unsqueeze(1)
        # # print(a_prime.shape)
        # # print(log_pi)
        # x_prime = torch.from_numpy(np.concatenate((s_prime,a_prime), axis=1)).float()
        # # print(x_prime.shape)
        # x_prime = x_prime.view(x_prime.size(0),-1)

        # max_q_prime = self.target_critic(x_prime)
        # pol_target = r + gamma * max_q_prime * done_mask
        # v?
        pol_target = q_out
        # print(q_out.shape, q_out[0])
        out = self.policy(s)
        # print(out.shape)
        # xx = torch.zeros(a.shape).long()
        log_pi = (F.log_softmax(out, dim=1)*F.softmax(out, dim=1)).sum(1).unsqueeze(1)
        # print(log_pi.shape)
        # pol_loss = (log_pi * (log_pi / self.reward_scale - pol_target)).mean()
        pol_loss = (log_pi / self.reward_scale - pol_target).mean()
        # print(pol_loss)
        self.policy_optimizer.zero_grad()
        disable_gradients(self.critic)
        pol_loss.backward()
        enable_gradients(self.critic)
        self.policy_optimizer.step()
      
    def sample_action(self, obs, epsilon):
        obs = obs.view(obs.size(0),-1)
        # print(obs.shape)
        out = self.policy(obs)
        coin = random.random()
        if coin < epsilon:
            return random.randint(0,17)
        else : 
            return out.argmax().item()
        # va = []
        # for i in range(18):
        #   a = torch.tensor(i).unsqueeze(0).unsqueeze(0)
        #   # print(a.shape)
        #   x = torch.from_numpy(np.concatenate((obs,a), axis=1)).float()
        #   q_out = self.critic(x)
        #   va.append(q_out.item())
        # # print("sdsadasdas")
        # print(np.argmax(np.array(va)))
        # return out.argmax().item()
            
# def train(q, q_target, memory, optimizer):
#     for i in range(10):
#         s,a,r,s_prime,done_mask = memory.sample(batch_size)

#         q_out = q(s)
#         q_a = q_out.gather(1,a)  # gather: select value according to the index
#         max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
#         target = r + gamma * max_q_prime * done_mask
#         loss = F.smooth_l1_loss(q_a, target)
        
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()

# %% [markdown]
# **SAC Train**
#
# ← You can download the videos from the videos folder in the files on the left

# %%
# setup the Gravitar ram environment, and record a video every 50 episodes. You can use the non-ram version here if you prefer、
import logging
env = gym.make('Gravitar-ram-v0')
env = gym.wrappers.Monitor(env, "drive/My Drive/rl/video1", video_callable=lambda episode_id: (episode_id%video_every)==0,force=True)

# reproducible environment and action spaces, do not change lines 6-11 here (tools > settings > editor > show line numbers)
seed = 742
torch.manual_seed(seed)
env.seed(seed)
random.seed(seed)
np.random.seed(seed)
env.action_space.seed(seed)

q = SAC()
# q_target = QNetwork()
# q_target.load_state_dict(q.state_dict())
memory = ReplayBuffer()

score    = 0.0
marking  = []
optimizer = optim.Adam(q.parameters(), lr=learning_rate)

for n_episode in range(int(1e32)):
    epsilon = 0.06
    s = env.reset()
    # print(len(s))
    done = False
    score = 0.0

    while True:
        # print(torch.from_numpy(s).float().shape)
        a = q.sample_action(torch.from_numpy(s).float().unsqueeze(0), epsilon)
        # print(a)
        s_prime, r, done, info = env.step(a)
        done_mask = 0.0 if done else 1.0
        memory.put((s,a,r/100.0,s_prime, done_mask))
        s = s_prime

        score += r
        if done:
            break
        
    if memory.size()>2000:
        # train(q, q_target, memory, optimizer)
        q.update_critic(memory)
        q.update_policy(memory)

    # do not change lines 44-48 here, they are for marking the submission log
    marking.append(score)
    if n_episode%100 == 0:
        print("marking, episode: {}, score: {:.1f}, mean_score: {:.2f}, std_score: {:.2f}".format(
            n_episode, score, np.array(marking).mean(), np.array(marking).std()))
        logging.basicConfig(level=logging.INFO, 
                  filename='gravitar-log.txt',
                  filemode='a',  
                  format='%(message)s')
                # print(len(batch['utilities']))
        logging.info("marking, episode: {}, score: {:.1f}, mean_score: {:.2f}, std_score: {:.2f}".format(
            n_episode, score, np.array(marking).mean(), np.array(marking).std()))
        marking = []

    # you can change this part, and print any data you like (so long as it doesn't start with "marking")
    if n_episode%print_every==0 and n_episode!=0:
        # q_target.load_state_dict(q.state_dict())
        hard_update(q.target_policy, q.policy)
        hard_update(q.target_critic, q.critic)
        print("episode: {}, score: {:.1f}, epsilon: {:.2f}".format(n_episode, score, epsilon))
# Out:
# marking, episode: 0, score: 100.0, mean_score: 100.00, std_score: 0.00
# episode: 5, score: 0.0, epsilon: 0.06
# episode: 10, score: 250.0, epsilon: 0.06
# episode: 15, score: 0.0, epsilon: 0.06
# episode: 20, score: 100.0, epsilon: 0.06
# episode: 25, score: 0.0, epsilon: 0.06
# episode: 30, score: 100.0, epsilon: 0.06
# episode: 35, score: 0.0, epsilon: 0.06
# episode: 40, score: 0.0, epsilon: 0.06
# episode: 45, score: 350.0, epsilon: 0.06
# episode: 50, score: 100.0, epsilon: 0.06
# episode: 55, score: 200.0, epsilon: 0.06
# episode: 60, score: 0.0, epsilon: 0.06
# episode: 65, score: 100.0, epsilon: 0.06
# episode: 70, score: 350.0, epsilon: 0.06
# episode: 75, score: 100.0, epsilon: 0.06
# episode: 80, score: 350.0, epsilon: 0.06
# episode: 85, score: 250.0, epsilon: 0.06
# episode: 90, score: 450.0, epsilon: 0.06
# episode: 95, score: 600.0, epsilon: 0.06
# marking, episode: 100, score: 250.0, mean_score: 184.00, std_score: 216.09
# episode: 100, score: 250.0, epsilon: 0.06
# episode: 105, score: 250.0, epsilon: 0.06
# episode: 110, score: 0.0, epsilon: 0.06
# episode: 115, score: 200.0, epsilon: 0.06
# episode: 120, score: 250.0, epsilon: 0.06
# episode: 125, score: 0.0, epsilon: 0.06
# episode: 130, score: 0.0, epsilon: 0.06
# episode: 135, score: 250.0, epsilon: 0.06
# episode: 140, score: 0.0, epsilon: 0.06
# episode: 145, score: 0.0, epsilon: 0.06
# episode: 150, score: 0.0, epsilon: 0.06
# episode: 155, score: 0.0, epsilon: 0.06
# episode: 160, score: 100.0, epsilon: 0.06
# episode: 165, score: 0.0, epsilon: 0.06
# episode: 170, score: 0.0, epsilon: 0.06
# episode: 175, score: 0.0, epsilon: 0.06
# episode: 180, score: 0.0, epsilon: 0.06
# episode: 185, score: 0.0, epsilon: 0.06
# episode: 190, score: 0.0, epsilon: 0.06
# episode: 195, score: 0.0, epsilon: 0.06
# marking, episode: 200, score: 0.0, mean_score: 145.50, std_score: 190.93
# episode: 200, score: 0.0, epsilon: 0.06
# episode: 205, score: 0.0, epsilon: 0.06
# episode: 210, score: 500.0, epsilon: 0.06
# episode: 215, score: 100.0, epsilon: 0.06
# episode: 220, score: 250.0, epsilon: 0.06
# episode: 225, score: 250.0, epsilon: 0.06
# episode: 230, score: 0.0, epsilon: 0.06
# episode: 235, score: 250.0, epsilon: 0.06
# episode: 240, score: 600.0, epsilon: 0.06
# episode: 245, score: 0.0, epsilon: 0.06
# episode: 250, score: 250.0, epsilon: 0.06
# episode: 255, score: 0.0, epsilon: 0.06
# episode: 260, score: 600.0, epsilon: 0.06
# episode: 265, score: 0.0, epsilon: 0.06
# episode: 270, score: 100.0, epsilon: 0.06
# episode: 275, score: 0.0, epsilon: 0.06
# episode: 280, score: 100.0, epsilon: 0.06
# episode: 285, score: 0.0, epsilon: 0.06
# episode: 290, score: 0.0, epsilon: 0.06
# episode: 295, score: 250.0, epsilon: 0.06
# marking, episode: 300, score: 100.0, mean_score: 217.50, std_score: 227.97
# episode: 300, score: 100.0, epsilon: 0.06
# episode: 305, score: 100.0, epsilon: 0.06
# episode: 310, score: 0.0, epsilon: 0.06
# episode: 315, score: 0.0, epsilon: 0.06
# episode: 320, score: 500.0, epsilon: 0.06
# episode: 325, score: 900.0, epsilon: 0.06
# episode: 330, score: 500.0, epsilon: 0.06
# episode: 335, score: 200.0, epsilon: 0.06
# episode: 340, score: 0.0, epsilon: 0.06
# episode: 345, score: 100.0, epsilon: 0.06
# episode: 350, score: 0.0, epsilon: 0.06
# episode: 355, score: 250.0, epsilon: 0.06
# episode: 360, score: 0.0, epsilon: 0.06
# episode: 365, score: 650.0, epsilon: 0.06
# episode: 370, score: 700.0, epsilon: 0.06
# episode: 375, score: 250.0, epsilon: 0.06
# episode: 380, score: 0.0, epsilon: 0.06
# episode: 385, score: 0.0, epsilon: 0.06
# episode: 390, score: 600.0, epsilon: 0.06
# episode: 395, score: 0.0, epsilon: 0.06
# marking, episode: 400, score: 0.0, mean_score: 157.00, std_score: 211.07
# episode: 400, score: 0.0, epsilon: 0.06
# episode: 405, score: 500.0, epsilon: 0.06
# episode: 410, score: 0.0, epsilon: 0.06
# episode: 415, score: 100.0, epsilon: 0.06
# episode: 420, score: 100.0, epsilon: 0.06
# episode: 425, score: 250.0, epsilon: 0.06
# episode: 430, score: 0.0, epsilon: 0.06
# episode: 435, score: 100.0, epsilon: 0.06
# episode: 440, score: 0.0, epsilon: 0.06
# episode: 445, score: 0.0, epsilon: 0.06
# episode: 450, score: 0.0, epsilon: 0.06
# episode: 455, score: 350.0, epsilon: 0.06
# episode: 460, score: 0.0, epsilon: 0.06
# episode: 465, score: 350.0, epsilon: 0.06
# episode: 470, score: 700.0, epsilon: 0.06
# episode: 475, score: 0.0, epsilon: 0.06
# episode: 480, score: 700.0, epsilon: 0.06
# episode: 485, score: 100.0, epsilon: 0.06
# episode: 490, score: 100.0, epsilon: 0.06
# episode: 495, score: 250.0, epsilon: 0.06
# marking, episode: 500, score: 350.0, mean_score: 167.50, std_score: 204.13
# episode: 500, score: 350.0, epsilon: 0.06
# episode: 505, score: 450.0, epsilon: 0.06
# episode: 510, score: 200.0, epsilon: 0.06
# episode: 515, score: 450.0, epsilon: 0.06
# episode: 520, score: 250.0, epsilon: 0.06
# episode: 525, score: 0.0, epsilon: 0.06
# episode: 530, score: 450.0, epsilon: 0.06
# episode: 535, score: 0.0, epsilon: 0.06
# episode: 540, score: 700.0, epsilon: 0.06
# episode: 545, score: 0.0, epsilon: 0.06
# episode: 550, score: 100.0, epsilon: 0.06
# episode: 555, score: 100.0, epsilon: 0.06
# episode: 560, score: 100.0, epsilon: 0.06
# episode: 565, score: 250.0, epsilon: 0.06
# episode: 570, score: 100.0, epsilon: 0.06
# episode: 575, score: 250.0, epsilon: 0.06
# episode: 580, score: 200.0, epsilon: 0.06
# episode: 585, score: 600.0, epsilon: 0.06
# episode: 590, score: 500.0, epsilon: 0.06
# episode: 595, score: 0.0, epsilon: 0.06
# marking, episode: 600, score: 0.0, mean_score: 188.50, std_score: 191.68
# episode: 600, score: 0.0, epsilon: 0.06
# episode: 605, score: 0.0, epsilon: 0.06
# episode: 610, score: 350.0, epsilon: 0.06
# episode: 615, score: 250.0, epsilon: 0.06
# episode: 620, score: 0.0, epsilon: 0.06
# episode: 625, score: 0.0, epsilon: 0.06
# episode: 630, score: 100.0, epsilon: 0.06
# episode: 635, score: 250.0, epsilon: 0.06
# episode: 640, score: 500.0, epsilon: 0.06
# episode: 645, score: 250.0, epsilon: 0.06
# episode: 650, score: 0.0, epsilon: 0.06
# episode: 655, score: 350.0, epsilon: 0.06
# episode: 660, score: 0.0, epsilon: 0.06
# episode: 665, score: 100.0, epsilon: 0.06
# episode: 670, score: 250.0, epsilon: 0.06
# episode: 675, score: 250.0, epsilon: 0.06
# episode: 680, score: 250.0, epsilon: 0.06
# episode: 685, score: 0.0, epsilon: 0.06
# episode: 690, score: 0.0, epsilon: 0.06
# episode: 695, score: 0.0, epsilon: 0.06
# marking, episode: 700, score: 0.0, mean_score: 173.00, std_score: 184.72
# episode: 700, score: 0.0, epsilon: 0.06
# episode: 705, score: 100.0, epsilon: 0.06
# episode: 710, score: 100.0, epsilon: 0.06
# episode: 715, score: 500.0, epsilon: 0.06
# episode: 720, score: 500.0, epsilon: 0.06
# episode: 725, score: 0.0, epsilon: 0.06
# episode: 730, score: 250.0, epsilon: 0.06
# episode: 735, score: 250.0, epsilon: 0.06
# episode: 740, score: 200.0, epsilon: 0.06
# episode: 745, score: 250.0, epsilon: 0.06
# episode: 750, score: 500.0, epsilon: 0.06
# episode: 755, score: 0.0, epsilon: 0.06
# episode: 760, score: 0.0, epsilon: 0.06
# episode: 765, score: 250.0, epsilon: 0.06
# episode: 770, score: 0.0, epsilon: 0.06
# episode: 775, score: 250.0, epsilon: 0.06
# episode: 780, score: 0.0, epsilon: 0.06
# episode: 785, score: 950.0, epsilon: 0.06
# episode: 790, score: 0.0, epsilon: 0.06
# episode: 795, score: 100.0, epsilon: 0.06
# marking, episode: 800, score: 0.0, mean_score: 195.50, std_score: 218.19
# episode: 800, score: 0.0, epsilon: 0.06
# episode: 805, score: 250.0, epsilon: 0.06
# episode: 810, score: 350.0, epsilon: 0.06
# episode: 815, score: 750.0, epsilon: 0.06
# episode: 820, score: 0.0, epsilon: 0.06
# episode: 825, score: 250.0, epsilon: 0.06
# episode: 830, score: 300.0, epsilon: 0.06
# episode: 835, score: 250.0, epsilon: 0.06
# episode: 840, score: 450.0, epsilon: 0.06
# episode: 845, score: 0.0, epsilon: 0.06
# episode: 850, score: 100.0, epsilon: 0.06
# episode: 855, score: 0.0, epsilon: 0.06
# episode: 860, score: 0.0, epsilon: 0.06
# episode: 865, score: 0.0, epsilon: 0.06
# episode: 870, score: 100.0, epsilon: 0.06
# episode: 875, score: 0.0, epsilon: 0.06
# episode: 880, score: 0.0, epsilon: 0.06
# episode: 885, score: 100.0, epsilon: 0.06
# episode: 890, score: 350.0, epsilon: 0.06
# episode: 895, score: 250.0, epsilon: 0.06
# marking, episode: 900, score: 0.0, mean_score: 156.50, std_score: 176.44
# episode: 900, score: 0.0, epsilon: 0.06
# episode: 905, score: 0.0, epsilon: 0.06
# episode: 910, score: 850.0, epsilon: 0.06
# episode: 915, score: 0.0, epsilon: 0.06
# episode: 920, score: 0.0, epsilon: 0.06
# episode: 925, score: 0.0, epsilon: 0.06
# episode: 930, score: 0.0, epsilon: 0.06
# episode: 935, score: 450.0, epsilon: 0.06
# episode: 940, score: 300.0, epsilon: 0.06
# episode: 945, score: 0.0, epsilon: 0.06
# episode: 950, score: 200.0, epsilon: 0.06
# episode: 955, score: 0.0, epsilon: 0.06
# episode: 960, score: 600.0, epsilon: 0.06
# episode: 965, score: 250.0, epsilon: 0.06
# episode: 970, score: 350.0, epsilon: 0.06
# episode: 975, score: 100.0, epsilon: 0.06
# episode: 980, score: 100.0, epsilon: 0.06
# episode: 985, score: 250.0, epsilon: 0.06
# episode: 990, score: 250.0, epsilon: 0.06
# episode: 995, score: 0.0, epsilon: 0.06
# marking, episode: 1000, score: 250.0, mean_score: 170.00, std_score: 206.03
# episode: 1000, score: 250.0, epsilon: 0.06
# episode: 1005, score: 0.0, epsilon: 0.06
# episode: 1010, score: 0.0, epsilon: 0.06
# episode: 1015, score: 500.0, epsilon: 0.06
# episode: 1020, score: 800.0, epsilon: 0.06
# episode: 1025, score: 0.0, epsilon: 0.06
# episode: 1030, score: 0.0, epsilon: 0.06
# episode: 1035, score: 0.0, epsilon: 0.06
# episode: 1040, score: 250.0, epsilon: 0.06
# episode: 1045, score: 0.0, epsilon: 0.06
# episode: 1050, score: 0.0, epsilon: 0.06
# episode: 1055, score: 450.0, epsilon: 0.06
# episode: 1060, score: 0.0, epsilon: 0.06
# episode: 1065, score: 100.0, epsilon: 0.06
# episode: 1070, score: 250.0, epsilon: 0.06
# episode: 1075, score: 0.0, epsilon: 0.06
# episode: 1080, score: 100.0, epsilon: 0.06
# episode: 1085, score: 100.0, epsilon: 0.06
# episode: 1090, score: 200.0, epsilon: 0.06
# episode: 1095, score: 100.0, epsilon: 0.06
# marking, episode: 1100, score: 100.0, mean_score: 125.00, std_score: 180.90
# episode: 1100, score: 100.0, epsilon: 0.06
# episode: 1105, score: 250.0, epsilon: 0.06
# episode: 1110, score: 250.0, epsilon: 0.06
# episode: 1115, score: 0.0, epsilon: 0.06
# episode: 1120, score: 100.0, epsilon: 0.06
# episode: 1125, score: 350.0, epsilon: 0.06
# episode: 1130, score: 200.0, epsilon: 0.06
# episode: 1135, score: 0.0, epsilon: 0.06
# episode: 1140, score: 0.0, epsilon: 0.06
# episode: 1145, score: 850.0, epsilon: 0.06
# episode: 1150, score: 350.0, epsilon: 0.06
# episode: 1155, score: 100.0, epsilon: 0.06
# episode: 1160, score: 0.0, epsilon: 0.06
# episode: 1165, score: 0.0, epsilon: 0.06
# episode: 1170, score: 0.0, epsilon: 0.06
# episode: 1175, score: 100.0, epsilon: 0.06
# episode: 1180, score: 0.0, epsilon: 0.06
# episode: 1185, score: 0.0, epsilon: 0.06
# episode: 1190, score: 100.0, epsilon: 0.06
# episode: 1195, score: 0.0, epsilon: 0.06
# marking, episode: 1200, score: 0.0, mean_score: 109.00, std_score: 168.73
# episode: 1200, score: 0.0, epsilon: 0.06
# episode: 1205, score: 200.0, epsilon: 0.06
# episode: 1210, score: 0.0, epsilon: 0.06
# episode: 1215, score: 0.0, epsilon: 0.06
# episode: 1220, score: 0.0, epsilon: 0.06
# episode: 1225, score: 100.0, epsilon: 0.06
# episode: 1230, score: 0.0, epsilon: 0.06
# episode: 1235, score: 0.0, epsilon: 0.06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-341a48cbbc53> in <module>()
#      30     while True:
#      31         # print(torch.from_numpy(s).float().shape)
# ---> 32         a = q.sample_action(torch.from_numpy(s).float().unsqueeze(0), epsilon)
#      33         # print(a)
#      34         s_prime, r, done, info = env.step(a)
#
# KeyboardInterrupt:
